# %%
from scipy.io import loadmat
import numpy as np

data_path = 'C:/Users/rachi/OneDrive/Documentos/Datasets/flickr30k'

# %%
query_data = loadmat(f'{data_path}/vgg_feats.mat')['feats']
query_data.shape
# Out:
# (4096, 31014)

# %%
new = np.transpose(query_data)
new.shape
# Out:
# (31014, 4096)

# %%
query_data[0]
# Out:
# array([ 2.7827373, -0.       ,  1.9144233, ..., -0.       , -0.       ,
#        -0.       ], dtype=float32)

# %%
catalogue_data = np.load(f'{data_path}/fasttext_feats.npy', allow_pickle=True)
catalogue_data.shape
# Out:
# (31014, 5)

# %%
catalogue_data
# Out:
# array([[array([[-2.86500603e-02, -6.10711891e-03,  1.07447125e-01, ...,
#          5.48986733e-01,  1.45856142e-02,  4.48770523e-02],
#        [ 3.24471332e-02, -1.05017692e-01, -4.19994742e-02, ...,
#          1.30625680e-01,  4.08617705e-02,  2.69446522e-02],
#        [ 1.14518881e-01,  1.34461056e-02,  8.47451240e-02, ...,
#          9.88778397e-02, -1.11780845e-01, -1.03979394e-01],
#        ...,
#        [-1.40470369e-02, -2.52174616e-01,  7.15019330e-02, ...,
#          1.37044221e-01,  4.51073935e-03,  3.29234600e-02],
#        [-5.17441928e-02,  7.39639550e-02, -1.30568799e-02, ...,
#          2.37025172e-01,  4.47519124e-04, -4.19306662e-03],
#        [ 2.94124745e-02, -2.34647058e-02, -4.84248847e-02, ...,
#         -5.64376405e-03,  1.51629925e-01,  1.32927716e-01]], dtype=float32),
#         array([[-0.02865006, -0.00610712,  0.10744713, ...,  0.54898673,
#          0.01458561,  0.04487705],
#        [ 0.03244713, -0.10501769, -0.04199947, ...,  0.13062568,
#          0.04086177,  0.02694465],
#        [ 0.03619979, -0.04231487, -0.03680481, ...,  0.14443137,
#         -0.00868567,  0.07062251],
#        ...,
#        [-0.05725129,  0.07031577, -0.06028128, ...,  0.00120388,
#          0.05798787, -0.0502275 ],
#        [-0.01288656, -0.01589274, -0.12144333, ...,  0.24839076,
#         -0.0148568 ,  0.06255094],
#        [-0.01764634, -0.04676102, -0.01789125, ...,  0.10908578,
#          0.14358206, -0.00706312]], dtype=float32),
#         array([[-0.02865006, -0.00610712,  0.10744713, ...,  0.54898673,
#          0.01458561,  0.04487705],
#        [ 0.2735906 , -0.06147717, -0.11545964, ...,  0.2113629 ,
#          0.17091118,  0.09382648],
#        [-0.01404704, -0.25217462,  0.07150193, ...,  0.13704422,
#          0.00451074,  0.03292346],
#        ...,
#        [-0.01404704, -0.25217462,  0.07150193, ...,  0.13704422,
#          0.00451074,  0.03292346],
#        [ 0.08764305, -0.49590126, -0.04985499, ...,  0.53485096,
#         -0.05581036, -0.01659843],
#        [ 0.02941247, -0.02346471, -0.04842488, ..., -0.00564376,
#          0.15162992,  0.13292772]], dtype=float32),
#         array([[ 0.08764305, -0.49590126, -0.04985499, ...,  0.53485096,
#         -0.05581036, -0.01659843],
#        [ 0.20510274, -0.11743978, -0.01554255, ...,  0.2640393 ,
#          0.10353443,  0.02857708],
#        [-0.01404704, -0.25217462,  0.07150193, ...,  0.13704422,
#          0.00451074,  0.03292346],
#        ...,
#        [-0.01404704, -0.25217462,  0.07150193, ...,  0.13704422,
#          0.00451074,  0.03292346],
#        [ 0.08764305, -0.49590126, -0.04985499, ...,  0.53485096,
#         -0.05581036, -0.01659843],
#        [-0.02484166,  0.01063355, -0.02659726, ...,  0.10762209,
#          0.06694858,  0.06396108]], dtype=float32),
#         array([[-0.02865006, -0.00610712,  0.10744713, ...,  0.54898673,
#          0.01458561,  0.04487705],
#        [ 0.04942417,  0.0140844 , -0.0833446 , ...,  0.07918321,
#         -0.04133154, -0.01532167],
#        [ 0.09996854,  0.01195208, -0.01650678, ..., -0.00582678,
#         -0.1089934 , -0.09838624],
#        [ 0.05373685,  0.05636049, -0.07640421, ...,  0.13914105,
#         -0.06804852, -0.01560708],
#        [-0.06896753,  0.0195751 ,  0.02158902, ..., -0.05849325,
#         -0.03000274, -0.02725632],
#        [-0.00873305,  0.00686786,  0.02456129, ...,  0.04205402,
#         -0.00813371,  0.02733298]], dtype=float32)],
#        [array([[-0.00068021, -0.00444374, -0.00131195, ...,  0.16503298,
#         -0.0020026 ,  0.0269782 ],
#        [ 0.2735906 , -0.06147717, -0.11545964, ...,  0.2113629 ,
#          0.17091118,  0.09382648],
#        [-0.01404704, -0.25217462,  0.07150193, ...,  0.13704422,
#          0.00451074,  0.03292346],
#        ...,
#        [-0.04752   , -0.13474728,  0.03587694, ...,  0.11620808,
#          0.05520337, -0.05990372],
#        [-0.14485092, -0.01888422,  0.0727995 , ...,  0.04553231,
#         -0.07373365, -0.04746109],
#        [-0.06489276, -0.01497137,  0.08029559, ...,  0.06085103,
#         -0.032644  ,  0.00791978]], dtype=float32),
#         array([[ 4.3025270e-02, -1.3263367e-02, -3.2398477e-02, ...,
#          6.3944601e-02,  1.4876661e-01,  1.1100858e-02],
#        [ 5.5500027e-02,  1.2373070e-02,  1.8384641e-01, ...,
#          8.0506191e-02,  4.8555177e-02, -5.5907540e-02],
#        [-4.4320565e-02, -3.4719906e-03, -7.2458774e-02, ...,
#          4.0904298e-02,  2.5505496e-02,  1.3788857e-02],
#        ...,
#        [ 5.3700097e-02,  1.0743038e-02,  5.1326461e-02, ...,
#          1.6585859e-02, -3.8298711e-02,  6.2435713e-02],
#        [-7.3038238e-05, -1.8774074e-01, -7.1051158e-02, ...,
#          2.8464055e-02, -1.3843335e-01,  1.8053975e-02],
#        [ 5.1279988e-02,  2.1920113e-02, -3.0650290e-02, ...,
#          4.0343959e-02,  7.9727229e-03, -9.0882786e-02]], dtype=float32),
#         array([[-2.86500603e-02, -6.10711891e-03,  1.07447125e-01, ...,
#          5.48986733e-01,  1.45856142e-02,  4.48770523e-02],
#        [ 2.73590595e-01, -6.14771694e-02, -1.15459636e-01, ...,
#          2.11362898e-01,  1.70911178e-01,  9.38264802e-02],
#        [-3.89517099e-03, -6.04084227e-03,  5.02631068e-02, ...,
#          2.62411609e-02, -1.65058672e-02,  6.55661616e-03],
#        ...,
#        [ 4.04246822e-02, -2.90683359e-02, -7.75740575e-03, ...,
#          9.99516249e-03,  3.32566127e-02, -3.56256142e-02],
#        [-5.02477251e-02, -2.64228731e-02,  3.09300795e-02, ...,
#          1.16092555e-01, -4.47191596e-02, -2.16265209e-04],
#        [ 1.46121264e-01,  1.70045272e-02, -4.41535562e-02, ...,
#          1.01418853e-01, -9.94824320e-02, -2.29379237e-02]], dtype=float32),
#         array([[-6.03021383e-02,  3.39822806e-02,  9.27066207e-02, ...,
#          3.93990606e-01,  4.72458750e-02, -1.27892345e-02],
#        [ 2.73590595e-01, -6.14771694e-02, -1.15459636e-01, ...,
#          2.11362898e-01,  1.70911178e-01,  9.38264802e-02],
#        [-5.68210557e-02,  5.49030602e-01,  1.31215438e-01, ...,
#         -3.34279984e-02, -6.33967221e-02, -6.05157577e-02],
#        ...,
#        [ 8.76430497e-02, -4.95901257e-01, -4.98549901e-02, ...,
#          5.34850955e-01, -5.58103584e-02, -1.65984333e-02],
#        [-1.65707133e-05, -1.21217720e-01, -1.61474645e-01, ...,
#          4.61112112e-02,  4.19680327e-02,  3.03020398e-03],
#        [-1.67076327e-02, -5.42800501e-03,  6.31302670e-02, ...,
#          4.19230759e-02, -6.51586987e-03,  1.19892210e-02]], dtype=float32),
#         array([[-0.01659028,  0.03084825,  0.06114368, ...,  0.2896176 ,
#          0.02328342,  0.00350537],
#        [ 0.2735906 , -0.06147717, -0.11545964, ...,  0.2113629 ,
#          0.17091118,  0.09382648],
#        [-0.05682106,  0.5490306 ,  0.13121544, ..., -0.033428  ,
#         -0.06339672, -0.06051576],
#        [ 0.08764305, -0.49590126, -0.04985499, ...,  0.53485096,
#         -0.05581036, -0.01659843],
#        [-0.02704021, -0.14175344, -0.07866313, ...,  0.12929478,
#         -0.00567243,  0.015203  ],
#        [ 0.15475553,  0.01026221,  0.01837273, ...,  0.13058172,
#          0.09487227, -0.32997173]], dtype=float32)],
#        [array([[ 8.7643050e-02, -4.9590126e-01, -4.9854990e-02, ...,
#          5.3485096e-01, -5.5810358e-02, -1.6598433e-02],
#        [ 6.1052050e-03,  3.6800999e-02,  4.3836888e-05, ...,
#          1.3139960e-01,  2.1361403e-02,  7.9942159e-03],
#        [-1.4047037e-02, -2.5217462e-01,  7.1501933e-02, ...,
#          1.3704422e-01,  4.5107394e-03,  3.2923460e-02],
#        ...,
#        [ 7.0963174e-02, -6.3144177e-01,  5.4297958e-02, ...,
#          8.4138715e-01, -8.9474209e-02, -2.2252632e-02],
#        [ 7.6957256e-02,  1.0829008e-01, -2.6618710e-02, ...,
#          1.0122210e-01, -1.1106397e-01, -2.0363864e-02],
#        [-1.4674992e-02, -1.0748990e-01,  1.8900411e-02, ...,
#          1.9703400e-01,  2.4982462e-02,  5.9845150e-02]], dtype=float32),
#         array([[ 8.76430497e-02, -4.95901257e-01, -4.98549901e-02, ...,
#          5.34850955e-01, -5.58103584e-02, -1.65984333e-02],
#        [ 4.93411766e-03, -3.99964228e-02, -4.28677909e-02, ...,
#          8.66402015e-02, -2.64300103e-03, -2.38934457e-02],
#        [ 1.15085326e-01,  1.49589507e-02, -2.28462592e-02, ...,
#          1.43012017e-01,  1.14770290e-02, -9.77337509e-02],
#        ...,
#        [ 8.76430497e-02, -4.95901257e-01, -4.98549901e-02, ...,
#          5.34850955e-01, -5.58103584e-02, -1.65984333e-02],
#        [ 4.23445702e-02, -7.04841837e-02, -1.18683800e-02, ...,
#          1.38130367e-01, -2.04808898e-02, -6.38033776e-03],
#        [ 7.46452883e-02, -5.84841054e-03,  9.07464772e-02, ...,
#          1.16681226e-01,  6.26125038e-02, -2.23712530e-04]], dtype=float32),
#         array([[ 0.08764305, -0.49590126, -0.04985499, ...,  0.53485096,
#         -0.05581036, -0.01659843],
#        [ 0.00493412, -0.03999642, -0.04286779, ...,  0.0866402 ,
#         -0.002643  , -0.02389345],
#        [ 0.11508533,  0.01495895, -0.02284626, ...,  0.14301202,
#          0.01147703, -0.09773375],
#        ...,
#        [ 0.00468114,  0.02812425, -0.02963145, ...,  0.32557455,
#         -0.05089639,  0.00715068],
#        [-0.02089103, -0.03945034, -0.01106632, ...,  0.39438844,
#          0.1734347 ,  0.14743704],
#        [ 0.02935252, -0.00799287, -0.03636978, ...,  0.0378026 ,
#          0.02228408, -0.08353761]], dtype=float32),
#         array([[ 0.08764305, -0.49590126, -0.04985499, ...,  0.53485096,
#         -0.05581036, -0.01659843],
#        [ 0.00493412, -0.03999642, -0.04286779, ...,  0.0866402 ,
#         -0.002643  , -0.02389345],
#        [ 0.11508533,  0.01495895, -0.02284626, ...,  0.14301202,
#          0.01147703, -0.09773375],
#        ...,
#        [ 0.08764305, -0.49590126, -0.04985499, ...,  0.53485096,
#         -0.05581036, -0.01659843],
#        [ 0.04234457, -0.07048418, -0.01186838, ...,  0.13813037,
#         -0.02048089, -0.00638034],
#        [ 0.02935252, -0.00799287, -0.03636978, ...,  0.0378026 ,
#          0.02228408, -0.08353761]], dtype=float32),
#         array([[ 0.08764305, -0.49590126, -0.04985499, ...,  0.53485096,
#         -0.05581036, -0.01659843],
#        [ 0.11508533,  0.01495895, -0.02284626, ...,  0.14301202,
#          0.01147703, -0.09773375],
#        [-0.05218216,  0.02117564,  0.13026807, ...,  0.02721417,
#         -0.00143527, -0.01920651],
#        ...,
#        [ 0.08764305, -0.49590126, -0.04985499, ...,  0.53485096,
#         -0.05581036, -0.01659843],
#        [ 0.04234457, -0.07048418, -0.01186838, ...,  0.13813037,
#         -0.02048089, -0.00638034],
#        [-0.02115567, -0.02100963,  0.00657855, ...,  0.0433668 ,
#          0.03335747,  0.00354184]], dtype=float32)],
#        ...,
#        [array([[-2.86500603e-02, -6.10711891e-03,  1.07447125e-01, ...,
#          5.48986733e-01,  1.45856142e-02,  4.48770523e-02],
#        [ 1.24496542e-01,  4.10342440e-02, -4.27335501e-04, ...,
#          1.33304447e-01,  4.08989117e-02,  1.40044272e-01],
#        [ 1.15017770e-02,  1.58231594e-02,  3.38051505e-02, ...,
#          4.30761054e-02,  2.42721941e-02, -1.49448328e-02],
#        ...,
#        [-2.31028181e-02,  4.53131609e-02, -8.04376788e-03, ...,
#          6.45286888e-02,  4.11921367e-02, -2.30967589e-02],
#        [ 1.31013673e-02, -1.47970207e-02,  1.40525922e-02, ...,
#          6.49247020e-02, -2.68766526e-02,  3.95324547e-03],
#        [ 6.46637380e-02,  7.51510784e-02, -3.68163995e-02, ...,
#          1.53026164e-01, -1.41331682e-03,  6.77083582e-02]], dtype=float32),
#         array([[-0.02865006, -0.00610712,  0.10744713, ...,  0.54898673,
#          0.01458561,  0.04487705],
#        [ 0.07438716, -0.01398776, -0.04366362, ...,  0.10288547,
#         -0.01558627, -0.03947536],
#        [ 0.01487318, -0.11520134, -0.02481307, ..., -0.02643698,
#         -0.03094182,  0.01431764],
#        ...,
#        [ 0.08764305, -0.49590126, -0.04985499, ...,  0.53485096,
#         -0.05581036, -0.01659843],
#        [-0.08068904, -0.00225636, -0.01278581, ...,  0.11785325,
#         -0.05192818,  0.08028469],
#        [ 0.04636247,  0.06747228,  0.02988704, ...,  0.13157597,
#         -0.05567303, -0.02595558]], dtype=float32),
#         array([[ 0.2735906 , -0.06147717, -0.11545964, ...,  0.2113629 ,
#          0.17091118,  0.09382648],
#        [-0.01404704, -0.25217462,  0.07150193, ...,  0.13704422,
#          0.00451074,  0.03292346],
#        [-0.01837889, -0.05680291, -0.02585004, ...,  0.11387236,
#          0.04477422, -0.02946881],
#        ...,
#        [ 0.08764305, -0.49590126, -0.04985499, ...,  0.53485096,
#         -0.05581036, -0.01659843],
#        [-0.08068904, -0.00225636, -0.01278581, ...,  0.11785325,
#         -0.05192818,  0.08028469],
#        [-0.10879573, -0.01031208, -0.01515565, ..., -0.02331287,
#          0.07489285,  0.01186862]], dtype=float32),
#         array([[ 2.73590595e-01, -6.14771694e-02, -1.15459636e-01, ...,
#          2.11362898e-01,  1.70911178e-01,  9.38264802e-02],
#        [-5.83947152e-02,  4.37172204e-02,  6.21997714e-02, ...,
#         -7.19211549e-02, -4.39998284e-02,  4.08459492e-02],
#        [-3.89517099e-03, -6.04084227e-03,  5.02631068e-02, ...,
#          2.62411609e-02, -1.65058672e-02,  6.55661616e-03],
#        ...,
#        [-7.30382380e-05, -1.87740743e-01, -7.10511580e-02, ...,
#          2.84640547e-02, -1.38433352e-01,  1.80539750e-02],
#        [ 8.76430497e-02, -4.95901257e-01, -4.98549901e-02, ...,
#          5.34850955e-01, -5.58103584e-02, -1.65984333e-02],
#        [ 5.58857471e-02, -1.22981174e-02, -5.16420007e-02, ...,
#          8.64674300e-02, -1.28026807e-03, -1.49949929e-02]], dtype=float32),
#         array([[-0.01714909,  0.01078323, -0.03997385, ...,  0.11149164,
#          0.05766493, -0.00652441],
#        [ 0.01937374, -0.01068419, -0.05177872, ...,  0.00448815,
#         -0.0053848 ,  0.00559388],
#        [ 0.02542906,  0.28642443,  0.16145039, ...,  0.14291927,
#         -0.07222278, -0.02931507],
#        ...,
#        [-0.20015332, -0.03355947, -0.1912339 , ...,  0.16980754,
#          0.02303607, -0.06129245],
#        [-0.03698739,  0.0420313 , -0.0356483 , ..., -0.03132047,
#         -0.0658702 ,  0.06050579],
#        [-0.00565158,  0.03897488, -0.01070335, ...,  0.07316079,
#          0.03698615, -0.01143277]], dtype=float32)],
#        [array([[ 7.0963174e-02, -6.3144177e-01,  5.4297958e-02, ...,
#          8.4138715e-01, -8.9474209e-02, -2.2252632e-02],
#        [ 3.4868941e-02,  5.4208306e-03,  8.0994591e-03, ...,
#          6.9929607e-02,  6.1269291e-04,  3.7029941e-02],
#        [ 5.5976756e-02,  2.0055424e-02,  2.6218077e-02, ...,
#          1.0477429e-01, -1.2351153e-01,  2.6337732e-02],
#        ...,
#        [ 8.7643050e-02, -4.9590126e-01, -4.9854990e-02, ...,
#          5.3485096e-01, -5.5810358e-02, -1.6598433e-02],
#        [ 2.7991273e-02, -2.3818118e-02,  3.3214360e-02, ...,
#          5.9578389e-02, -9.1267657e-03,  1.5541449e-02],
#        [ 1.3245508e-01,  1.5343154e-02, -5.7937680e-03, ...,
#          6.5693431e-02,  1.0399933e-02, -9.4149247e-02]], dtype=float32),
#         array([[-0.02241497,  0.09303343,  0.05821983, ...,  0.21794516,
#         -0.03021447,  0.02800532],
#        [-0.09776052, -0.20827363, -0.10372388, ..., -0.22816789,
#         -0.22443864,  0.08897465],
#        [ 0.08764305, -0.49590126, -0.04985499, ...,  0.53485096,
#         -0.05581036, -0.01659843],
#        ...,
#        [-0.01404704, -0.25217462,  0.07150193, ...,  0.13704422,
#          0.00451074,  0.03292346],
#        [ 0.05882466,  0.02039707, -0.05951786, ...,  0.36633506,
#         -0.0306768 ,  0.06866188],
#        [ 0.08848751,  0.08234244,  0.05536418, ...,  0.16908193,
#          0.01807731, -0.03965668]], dtype=float32),
#         array([[ 8.7643050e-02, -4.9590126e-01, -4.9854990e-02, ...,
#          5.3485096e-01, -5.5810358e-02, -1.6598433e-02],
#        [ 3.4868941e-02,  5.4208306e-03,  8.0994591e-03, ...,
#          6.9929607e-02,  6.1269291e-04,  3.7029941e-02],
#        [ 7.5159766e-02, -6.7383751e-02,  1.0597507e-02, ...,
#          1.5557860e-01, -7.4518457e-02, -5.0140604e-02],
#        ...,
#        [-5.6821056e-02,  5.4903060e-01,  1.3121544e-01, ...,
#         -3.3427998e-02, -6.3396722e-02, -6.0515758e-02],
#        [-5.1744193e-02,  7.3963955e-02, -1.3056880e-02, ...,
#          2.3702517e-01,  4.4751912e-04, -4.1930666e-03],
#        [-3.6322188e-02,  5.1860344e-02, -2.9364580e-02, ...,
#          7.7924661e-02,  9.5710214e-03,  2.8699406e-03]], dtype=float32),
#         array([[ 0.07096317, -0.6314418 ,  0.05429796, ...,  0.84138715,
#         -0.08947421, -0.02225263],
#        [ 0.04179472, -0.06618921, -0.06772535, ...,  0.0586566 ,
#          0.10996671,  0.03767878],
#        [ 0.20510274, -0.11743978, -0.01554255, ...,  0.2640393 ,
#          0.10353443,  0.02857708],
#        ...,
#        [ 0.01487318, -0.11520134, -0.02481307, ..., -0.02643698,
#         -0.03094182,  0.01431764],
#        [ 0.08764305, -0.49590126, -0.04985499, ...,  0.53485096,
#         -0.05581036, -0.01659843],
#        [ 0.24535057,  0.08538281, -0.1435298 , ...,  0.01994606,
#         -0.10234755, -0.09027161]], dtype=float32),
#         array([[ 0.07096317, -0.6314418 ,  0.05429796, ...,  0.84138715,
#         -0.08947421, -0.02225263],
#        [ 0.04179472, -0.06618921, -0.06772535, ...,  0.0586566 ,
#          0.10996671,  0.03767878],
#        [ 0.07237765, -0.00649219, -0.03631059, ...,  0.05914442,
#         -0.01140269,  0.00633319],
#        ...,
#        [ 0.03096944,  0.03377876, -0.06515609, ...,  0.04788275,
#          0.12519166, -0.00866976],
#        [ 0.0163837 , -0.06461791, -0.02076162, ..., -0.03546793,
#          0.01789529,  0.03848195],
#        [-0.02358276,  0.00741944,  0.1480076 , ...,  0.15488778,
#         -0.03862552, -0.07607283]], dtype=float32)],
#        [array([[ 8.76430497e-02, -4.95901257e-01, -4.98549901e-02, ...,
#          5.34850955e-01, -5.58103584e-02, -1.65984333e-02],
#        [ 2.05102742e-01, -1.17439777e-01, -1.55425537e-02, ...,
#          2.64039308e-01,  1.03534430e-01,  2.85770763e-02],
#        [-1.40470369e-02, -2.52174616e-01,  7.15019330e-02, ...,
#          1.37044221e-01,  4.51073935e-03,  3.29234600e-02],
#        ...,
#        [-1.40470369e-02, -2.52174616e-01,  7.15019330e-02, ...,
#          1.37044221e-01,  4.51073935e-03,  3.29234600e-02],
#        [-5.17441928e-02,  7.39639550e-02, -1.30568799e-02, ...,
#          2.37025172e-01,  4.47519124e-04, -4.19306662e-03],
#        [ 4.07749563e-02,  2.56321225e-02,  2.53146589e-02, ...,
#          3.74942832e-02, -1.32345855e-02, -1.94678828e-03]], dtype=float32),
#         array([[ 0.08764305, -0.49590126, -0.04985499, ...,  0.53485096,
#         -0.05581036, -0.01659843],
#        [ 0.03244713, -0.10501769, -0.04199947, ...,  0.13062568,
#          0.04086177,  0.02694465],
#        [ 0.20510274, -0.11743978, -0.01554255, ...,  0.2640393 ,
#          0.10353443,  0.02857708],
#        ...,
#        [-0.06604708, -0.02313196, -0.07449847, ...,  0.18585357,
#         -0.02000536, -0.09603785],
#        [-0.05574067, -0.01901752,  0.0680063 , ..., -0.03469824,
#          0.01071329,  0.00859086],
#        [ 0.00371716, -0.24187279, -0.08966686, ...,  1.0584562 ,
#         -0.02168053, -0.10592619]], dtype=float32),
#         array([[ 8.7643050e-02, -4.9590126e-01, -4.9854990e-02, ...,
#          5.3485096e-01, -5.5810358e-02, -1.6598433e-02],
#        [ 2.0510274e-01, -1.1743978e-01, -1.5542554e-02, ...,
#          2.6403931e-01,  1.0353443e-01,  2.8577076e-02],
#        [-9.7760521e-02, -2.0827363e-01, -1.0372388e-01, ...,
#         -2.2816789e-01, -2.2443864e-01,  8.8974647e-02],
#        ...,
#        [-7.9498328e-03,  2.9485475e-03,  4.2435467e-02, ...,
#          1.7832369e-01,  1.4505401e-01,  4.6579421e-02],
#        [-7.3038238e-05, -1.8774074e-01, -7.1051158e-02, ...,
#          2.8464055e-02, -1.3843335e-01,  1.8053975e-02],
#        [-2.7647693e-02,  1.0620716e-01, -1.8430775e-02, ...,
#          1.4580601e-01,  8.6692542e-02, -6.6310823e-02]], dtype=float32),
#         array([[ 8.76430497e-02, -4.95901257e-01, -4.98549901e-02, ...,
#          5.34850955e-01, -5.58103584e-02, -1.65984333e-02],
#        [ 2.05102742e-01, -1.17439777e-01, -1.55425537e-02, ...,
#          2.64039308e-01,  1.03534430e-01,  2.85770763e-02],
#        [ 1.10556744e-01,  4.85158712e-02,  1.36836770e-03, ...,
#          4.45967279e-02, -7.58901192e-03, -1.08113766e-01],
#        ...,
#        [-1.40470369e-02, -2.52174616e-01,  7.15019330e-02, ...,
#          1.37044221e-01,  4.51073935e-03,  3.29234600e-02],
#        [-5.17441928e-02,  7.39639550e-02, -1.30568799e-02, ...,
#          2.37025172e-01,  4.47519124e-04, -4.19306662e-03],
#        [ 4.07749563e-02,  2.56321225e-02,  2.53146589e-02, ...,
#          3.74942832e-02, -1.32345855e-02, -1.94678828e-03]], dtype=float32),
#         array([[ 8.76430497e-02, -4.95901257e-01, -4.98549901e-02, ...,
#          5.34850955e-01, -5.58103584e-02, -1.65984333e-02],
#        [ 2.05102742e-01, -1.17439777e-01, -1.55425537e-02, ...,
#          2.64039308e-01,  1.03534430e-01,  2.85770763e-02],
#        [-5.68210557e-02,  5.49030602e-01,  1.31215438e-01, ...,
#         -3.34279984e-02, -6.33967221e-02, -6.05157577e-02],
#        ...,
#        [-1.40470369e-02, -2.52174616e-01,  7.15019330e-02, ...,
#          1.37044221e-01,  4.51073935e-03,  3.29234600e-02],
#        [-5.17441928e-02,  7.39639550e-02, -1.30568799e-02, ...,
#          2.37025172e-01,  4.47519124e-04, -4.19306662e-03],
#        [ 4.07749563e-02,  2.56321225e-02,  2.53146589e-02, ...,
#          3.74942832e-02, -1.32345855e-02, -1.94678828e-03]], dtype=float32)]],
#       dtype=object)

# %%
img_texts = []
for i in range(len(catalogue_data)):
    #query_data[i] = dat
    sentences = []
    for sent in catalogue_data[i]:
        sentences.append(np.mean(sent, axis=0))
    img_texts.append(sentences)

len(img_texts)
# Out:
# 31014

# %%
np.asarray(img_texts).shape
# Out:
# (31014, 5, 300)

# %%
import json


with open(f'{data_path}/train.json') as f:
   train_data = json.load(f)

with open(f'{data_path}/val.json') as f:
   val_data = json.load(f)

with open(f'{data_path}/test.json') as f:
   test_data = json.load(f)

print('Length Train data: {}'.format(len(train_data)))
print('Length Validation data: {}'.format(len(val_data)))
print('Length Test data: {}'.format(len(test_data)))
# Out:
# Length Train data: 29000
# Length Validation data: 1014
# Length Test data: 1000

# %%
train_data
# Out:
# [{'sentids': [0, 1, 2, 3, 4],
#   'imgid': 0,
#   'sentences': [{'tokens': ['two',
#      'young',
#      'guys',
#      'with',
#      'shaggy',
#      'hair',
#      'look',
#      'at',
#      'their',
#      'hands',
#      'while',
#      'hanging',
#      'out',
#      'in',
#      'the',
#      'yard'],
#     'raw': 'Two young guys with shaggy hair look at their hands while hanging out in the yard.',
#     'imgid': 0,
#     'sentid': 0},
#    {'tokens': ['two',
#      'young',
#      'white',
#      'males',
#      'are',
#      'outside',
#      'near',
#      'many',
#      'bushes'],
#     'raw': 'Two young, White males are outside near many bushes.',
#     'imgid': 0,
#     'sentid': 1},
#    {'tokens': ['two',
#      'men',
#      'in',
#      'green',
#      'shirts',
#      'are',
#      'standing',
#      'in',
#      'a',
#      'yard'],
#     'raw': 'Two men in green shirts are standing in a yard.',
#     'imgid': 0,
#     'sentid': 2},
#    {'tokens': ['a',
#      'man',
#      'in',
#      'a',
#      'blue',
#      'shirt',
#      'standing',
#      'in',
#      'a',
#      'garden'],
#     'raw': 'A man in a blue shirt standing in a garden.',
#     'imgid': 0,
#     'sentid': 3},
#    {'tokens': ['two', 'friends', 'enjoy', 'time', 'spent', 'together'],
#     'raw': 'Two friends enjoy time spent together.',
#     'imgid': 0,
#     'sentid': 4}],
#   'split': 'train',
#   'filename': '1000092795.jpg'},
#  {'sentids': [5, 6, 7, 8, 9],
#   'imgid': 1,
#   'sentences': [{'tokens': ['several',
#      'men',
#      'in',
#      'hard',
#      'hats',
#      'are',
#      'operating',
#      'a',
#      'giant',
#      'pulley',
#      'system'],
#     'raw': 'Several men in hard hats are operating a giant pulley system.',
#     'imgid': 1,
#     'sentid': 5},
#    {'tokens': ['workers',
#      'look',
#      'down',
#      'from',
#      'up',
#      'above',
#      'on',
#      'a',
#      'piece',
#      'of',
#      'equipment'],
#     'raw': 'Workers look down from up above on a piece of equipment.',
#     'imgid': 1,
#     'sentid': 6},
#    {'tokens': ['two',
#      'men',
#      'working',
#      'on',
#      'a',
#      'machine',
#      'wearing',
#      'hard',
#      'hats'],
#     'raw': 'Two men working on a machine wearing hard hats.',
#     'imgid': 1,
#     'sentid': 7},
#    {'tokens': ['four', 'men', 'on', 'top', 'of', 'a', 'tall', 'structure'],
#     'raw': 'Four men on top of a tall structure.',
#     'imgid': 1,
#     'sentid': 8},
#    {'tokens': ['three', 'men', 'on', 'a', 'large', 'rig'],
#     'raw': 'Three men on a large rig.',
#     'imgid': 1,
#     'sentid': 9}],
#   'split': 'train',
#   'filename': '10002456.jpg'},
#  {'sentids': [10, 11, 12, 13, 14],
#   'imgid': 2,
#   'sentences': [{'tokens': ['a',
#      'child',
#      'in',
#      'a',
#      'pink',
#      'dress',
#      'is',
#      'climbing',
#      'up',
#      'a',
#      'set',
#      'of',
#      'stairs',
#      'in',
#      'an',
#      'entry',
#      'way'],
#     'raw': 'A child in a pink dress is climbing up a set of stairs in an entry way.',
#     'imgid': 2,
#     'sentid': 10},
#    {'tokens': ['a',
#      'little',
#      'girl',
#      'in',
#      'a',
#      'pink',
#      'dress',
#      'going',
#      'into',
#      'a',
#      'wooden',
#      'cabin'],
#     'raw': 'A little girl in a pink dress going into a wooden cabin.',
#     'imgid': 2,
#     'sentid': 11},
#    {'tokens': ['a',
#      'little',
#      'girl',
#      'climbing',
#      'the',
#      'stairs',
#      'to',
#      'her',
#      'playhouse'],
#     'raw': 'A little girl climbing the stairs to her playhouse.',
#     'imgid': 2,
#     'sentid': 12},
#    {'tokens': ['a',
#      'little',
#      'girl',
#      'climbing',
#      'into',
#      'a',
#      'wooden',
#      'playhouse'],
#     'raw': 'A little girl climbing into a wooden playhouse.',
#     'imgid': 2,
#     'sentid': 13},
#    {'tokens': ['a', 'girl', 'going', 'into', 'a', 'wooden', 'building'],
#     'raw': 'A girl going into a wooden building.',
#     'imgid': 2,
#     'sentid': 14}],
#   'split': 'train',
#   'filename': '1000268201.jpg'},
#  {'sentids': [15, 16, 17, 18, 19],
#   'imgid': 3,
#   'sentences': [{'tokens': ['someone',
#      'in',
#      'a',
#      'blue',
#      'shirt',
#      'and',
#      'hat',
#      'is',
#      'standing',
#      'on',
#      'stair',
#      'and',
#      'leaning',
#      'against',
#      'a',
#      'window'],
#     'raw': 'Someone in a blue shirt and hat is standing on stair and leaning against a window.',
#     'imgid': 3,
#     'sentid': 15},
#    {'tokens': ['a',
#      'man',
#      'in',
#      'a',
#      'blue',
#      'shirt',
#      'is',
#      'standing',
#      'on',
#      'a',
#      'ladder',
#      'cleaning',
#      'a',
#      'window'],
#     'raw': 'A man in a blue shirt is standing on a ladder cleaning a window.',
#     'imgid': 3,
#     'sentid': 16},
#    {'tokens': ['a',
#      'man',
#      'on',
#      'a',
#      'ladder',
#      'cleans',
#      'the',
#      'window',
#      'of',
#      'a',
#      'tall',
#      'building'],
#     'raw': 'A man on a ladder cleans the window of a tall building.',
#     'imgid': 3,
#     'sentid': 17},
#    {'tokens': ['man',
#      'in',
#      'blue',
#      'shirt',
#      'and',
#      'jeans',
#      'on',
#      'ladder',
#      'cleaning',
#      'windows'],
#     'raw': 'Man in blue shirt and jeans on ladder cleaning windows',
#     'imgid': 3,
#     'sentid': 18},
#    {'tokens': ['a', 'man', 'on', 'a', 'ladder', 'cleans', 'a', 'window'],
#     'raw': 'A man on a ladder cleans a window',
#     'imgid': 3,
#     'sentid': 19}],
#   'split': 'train',
#   'filename': '1000344755.jpg'},
#  {'sentids': [20, 21, 22, 23, 24],
#   'imgid': 4,
#   'sentences': [{'tokens': ['two',
#      'men',
#      'one',
#      'in',
#      'a',
#      'gray',
#      'shirt',
#      'one',
#      'in',
#      'a',
#      'black',
#      'shirt',
#      'standing',
#      'near',
#      'a',
#      'stove'],
#     'raw': 'Two men, one in a gray shirt, one in a black shirt, standing near a stove.',
#     'imgid': 4,
#     'sentid': 20},
#    {'tokens': ['two',
#      'guy',
#      'cooking',
#      'and',
#      'joking',
#      'around',
#      'with',
#      'the',
#      'camera'],
#     'raw': 'Two guy cooking and joking around with the camera.',
#     'imgid': 4,
#     'sentid': 21},
#    {'tokens': ['two',
#      'men',
#      'in',
#      'a',
#      'kitchen',
#      'cooking',
#      'food',
#      'on',
#      'a',
#      'stove'],
#     'raw': 'Two men in a kitchen cooking food on a stove.',
#     'imgid': 4,
#     'sentid': 22},
#    {'tokens': ['two', 'men', 'are', 'at', 'the', 'stove', 'preparing', 'food'],
#     'raw': 'Two men are at the stove preparing food.',
#     'imgid': 4,
#     'sentid': 23},
#    {'tokens': ['two', 'men', 'are', 'cooking', 'a', 'meal'],
#     'raw': 'Two men are cooking a meal.',
#     'imgid': 4,
#     'sentid': 24}],
#   'split': 'train',
#   'filename': '1000366164.jpg'},
#  {'sentids': [25, 26, 27, 28, 29],
#   'imgid': 5,
#   'sentences': [{'tokens': ['two',
#      'people',
#      'in',
#      'the',
#      'photo',
#      'are',
#      'playing',
#      'the',
#      'guitar',
#      'and',
#      'the',
#      'other',
#      'is',
#      'poking',
#      'at',
#      'him'],
#     'raw': 'Two people in the photo are playing the guitar and the other is poking at him.',
#     'imgid': 5,
#     'sentid': 25},
#    {'tokens': ['a',
#      'man',
#      'in',
#      'green',
#      'holds',
#      'a',
#      'guitar',
#      'while',
#      'the',
#      'other',
#      'man',
#      'observes',
#      'his',
#      'shirt'],
#     'raw': 'A man in green holds a guitar while the other man observes his shirt.',
#     'imgid': 5,
#     'sentid': 26},
#    {'tokens': ['a',
#      'man',
#      'is',
#      'fixing',
#      'the',
#      'guitar',
#      'players',
#      'costume'],
#     'raw': 'A man is fixing the guitar players costume.',
#     'imgid': 5,
#     'sentid': 27},
#    {'tokens': ['a', 'guy', 'stitching', 'up', 'another', 'mans', 'coat'],
#     'raw': "A guy stitching up another man's coat.",
#     'imgid': 5,
#     'sentid': 28},
#    {'tokens': ['the', 'two', 'boys', 'playing', 'guitar'],
#     'raw': 'The two boys playing guitar',
#     'imgid': 5,
#     'sentid': 29}],
#   'split': 'train',
#   'filename': '1000523639.jpg'},
#  {'sentids': [30, 31, 32, 33, 34],
#   'imgid': 6,
#   'sentences': [{'tokens': ['a',
#      'man',
#      'sits',
#      'in',
#      'a',
#      'chair',
#      'while',
#      'holding',
#      'a',
#      'large',
#      'stuffed',
#      'animal',
#      'of',
#      'a',
#      'lion'],
#     'raw': 'A man sits in a chair while holding a large stuffed animal of a lion.',
#     'imgid': 6,
#     'sentid': 30},
#    {'tokens': ['a',
#      'man',
#      'is',
#      'sitting',
#      'on',
#      'a',
#      'chair',
#      'holding',
#      'a',
#      'large',
#      'stuffed',
#      'animal'],
#     'raw': 'A man is sitting on a chair holding a large stuffed animal.',
#     'imgid': 6,
#     'sentid': 31},
#    {'tokens': ['a',
#      'man',
#      'completes',
#      'the',
#      'finishing',
#      'touches',
#      'on',
#      'a',
#      'stuffed',
#      'lion'],
#     'raw': 'A man completes the finishing touches on a stuffed lion.',
#     'imgid': 6,
#     'sentid': 32},
#    {'tokens': ['a', 'man', 'holds', 'a', 'large', 'stuffed', 'lion', 'toy'],
#     'raw': 'A man holds a large stuffed lion toy.',
#     'imgid': 6,
#     'sentid': 33},
#    {'tokens': ['a', 'man', 'is', 'smiling', 'at', 'a', 'stuffed', 'lion'],
#     'raw': 'A man is smiling at a stuffed lion',
#     'imgid': 6,
#     'sentid': 34}],
#   'split': 'train',
#   'filename': '1000919630.jpg'},
#  {'sentids': [35, 36, 37, 38, 39],
#   'imgid': 7,
#   'sentences': [{'tokens': ['a',
#      'girl',
#      'is',
#      'on',
#      'rollerskates',
#      'talking',
#      'on',
#      'her',
#      'cellphone',
#      'standing',
#      'in',
#      'a',
#      'parking',
#      'lot'],
#     'raw': 'A girl is on rollerskates talking on her cellphone standing in a parking lot.',
#     'imgid': 7,
#     'sentid': 35},
#    {'tokens': ['a',
#      'trendy',
#      'girl',
#      'talking',
#      'on',
#      'her',
#      'cellphone',
#      'while',
#      'gliding',
#      'slowly',
#      'down',
#      'the',
#      'street'],
#     'raw': 'A trendy girl talking on her cellphone while gliding slowly down the street.',
#     'imgid': 7,
#     'sentid': 36},
#    {'tokens': ['a',
#      'young',
#      'adult',
#      'wearing',
#      'rollerblades',
#      'holding',
#      'a',
#      'cellular',
#      'phone',
#      'to',
#      'her',
#      'ear'],
#     'raw': 'A young adult wearing rollerblades, holding a cellular phone to her ear.',
#     'imgid': 7,
#     'sentid': 37},
#    {'tokens': ['there',
#      'is',
#      'a',
#      'young',
#      'girl',
#      'on',
#      'her',
#      'cellphone',
#      'while',
#      'skating'],
#     'raw': 'There is a young girl on her cellphone while skating.',
#     'imgid': 7,
#     'sentid': 38},
#    {'tokens': ['woman',
#      'talking',
#      'on',
#      'cellphone',
#      'and',
#      'wearing',
#      'rollerskates'],
#     'raw': 'Woman talking on cellphone and wearing rollerskates.',
#     'imgid': 7,
#     'sentid': 39}],
#   'split': 'train',
#   'filename': '10010052.jpg'},
#  {'sentids': [40, 41, 42, 43, 44],
#   'imgid': 8,
#   'sentences': [{'tokens': ['an',
#      'asian',
#      'man',
#      'wearing',
#      'a',
#      'black',
#      'suit',
#      'stands',
#      'near',
#      'a',
#      'dark',
#      'haired',
#      'woman',
#      'and',
#      'a',
#      'brown',
#      'haired',
#      'woman'],
#     'raw': 'An asian man wearing a black suit stands near a dark-haired woman and a brown-haired woman.',
#     'imgid': 8,
#     'sentid': 40},
#    {'tokens': ['three',
#      'people',
#      'are',
#      'standing',
#      'outside',
#      'near',
#      'large',
#      'pipes',
#      'and',
#      'a',
#      'metal',
#      'railing'],
#     'raw': 'Three people are standing outside near large pipes and a metal railing.',
#     'imgid': 8,
#     'sentid': 41},
#    {'tokens': ['a',
#      'young',
#      'woman',
#      'walks',
#      'past',
#      'two',
#      'young',
#      'people',
#      'dressed',
#      'in',
#      'hip',
#      'black',
#      'outfits'],
#     'raw': 'A young woman walks past two young people dressed in hip black outfits.',
#     'imgid': 8,
#     'sentid': 42},
#    {'tokens': ['a',
#      'woman',
#      'with',
#      'a',
#      'large',
#      'purse',
#      'is',
#      'walking',
#      'by',
#      'a',
#      'gate'],
#     'raw': 'A woman with a large purse is walking by a gate.',
#     'imgid': 8,
#     'sentid': 43},
#    {'tokens': ['several', 'people', 'standing', 'outside', 'a', 'building'],
#     'raw': 'Several people standing outside a building.',
#     'imgid': 8,
#     'sentid': 44}],
#   'split': 'train',
#   'filename': '1001465944.jpg'},
#  {'sentids': [45, 46, 47, 48, 49],
#   'imgid': 9,
#   'sentences': [{'tokens': ['two',
#      'men',
#      'in',
#      'germany',
#      'jumping',
#      'over',
#      'a',
#      'rail',
#      'at',
#      'the',
#      'same',
#      'time',
#      'without',
#      'shirts'],
#     'raw': 'Two men in Germany jumping over a rail at the same time without shirts.',
#     'imgid': 9,
#     'sentid': 45},
#    {'tokens': ['two',
#      'youths',
#      'are',
#      'jumping',
#      'over',
#      'a',
#      'roadside',
#      'railing',
#      'at',
#      'night'],
#     'raw': 'Two youths are jumping over a roadside railing, at night.',
#     'imgid': 9,
#     'sentid': 46},
#    {'tokens': ['boys',
#      'dancing',
#      'on',
#      'poles',
#      'in',
#      'the',
#      'middle',
#      'of',
#      'the',
#      'night'],
#     'raw': 'Boys dancing on poles in the middle of the night.',
#     'imgid': 9,
#     'sentid': 47},
#    {'tokens': ['two',
#      'men',
#      'with',
#      'no',
#      'shirts',
#      'jumping',
#      'over',
#      'a',
#      'rail'],
#     'raw': 'Two men with no shirts jumping over a rail.',
#     'imgid': 9,
#     'sentid': 48},
#    {'tokens': ['two', 'guys', 'jumping', 'over', 'a', 'gate', 'together'],
#     'raw': 'Two guys jumping over a gate together',
#     'imgid': 9,
#     'sentid': 49}],
#   'split': 'train',
#   'filename': '1001545525.jpg'},
#  {'sentids': [50, 51, 52, 53, 54],
#   'imgid': 10,
#   'sentences': [{'tokens': ['five',
#      'ballet',
#      'dancers',
#      'caught',
#      'mid',
#      'jump',
#      'in',
#      'a',
#      'dancing',
#      'studio',
#      'with',
#      'sunlight',
#      'coming',
#      'through',
#      'a',
#      'window'],
#     'raw': 'Five ballet dancers caught mid jump in a dancing studio with sunlight coming through a window.',
#     'imgid': 10,
#     'sentid': 50},
#    {'tokens': ['ballet',
#      'dancers',
#      'in',
#      'a',
#      'studio',
#      'practice',
#      'jumping',
#      'with',
#      'wonderful',
#      'form'],
#     'raw': 'Ballet dancers in a studio practice jumping with wonderful form.',
#     'imgid': 10,
#     'sentid': 51},
#    {'tokens': ['five',
#      'girls',
#      'are',
#      'leaping',
#      'simultaneously',
#      'in',
#      'a',
#      'dance',
#      'practice',
#      'room'],
#     'raw': 'Five girls are leaping simultaneously in a dance practice room.',
#     'imgid': 10,
#     'sentid': 52},
#    {'tokens': ['five',
#      'girls',
#      'dancing',
#      'and',
#      'bending',
#      'feet',
#      'in',
#      'ballet',
#      'class'],
#     'raw': 'Five girls dancing and bending feet in ballet class.',
#     'imgid': 10,
#     'sentid': 53},
#    {'tokens': ['a',
#      'ballet',
#      'class',
#      'of',
#      'five',
#      'girls',
#      'jumping',
#      'in',
#      'sequence'],
#     'raw': 'A ballet class of five girls jumping in sequence.',
#     'imgid': 10,
#     'sentid': 54}],
#   'split': 'train',
#   'filename': '1001573224.jpg'},
#  {'sentids': [55, 56, 57, 58, 59],
#   'imgid': 11,
#   'sentences': [{'tokens': ['three',
#      'young',
#      'men',
#      'and',
#      'a',
#      'young',
#      'woman',
#      'wearing',
#      'sneakers',
#      'are',
#      'leaping',
#      'in',
#      'midair',
#      'at',
#      'the',
#      'top',
#      'of',
#      'a',
#      'flight',
#      'of',
#      'concrete',
#      'stairs'],
#     'raw': 'Three young men and a young woman wearing sneakers are leaping in midair at the top of a flight of concrete stairs.',
#     'imgid': 11,
#     'sentid': 55},
#    {'tokens': ['four',
#      'casually',
#      'dressed',
#      'guys',
#      'jumping',
#      'down',
#      'a',
#      'stairway',
#      'outdoors',
#      'with',
#      'a',
#      'stone',
#      'wall',
#      'behind',
#      'them'],
#     'raw': 'Four casually dressed guys jumping down a stairway outdoors with a stone wall behind them.',
#     'imgid': 11,
#     'sentid': 56},
#    {'tokens': ['four',
#      'guys',
#      'three',
#      'wearing',
#      'hats',
#      'one',
#      'not',
#      'are',
#      'jumping',
#      'at',
#      'the',
#      'top',
#      'of',
#      'a',
#      'staircase'],
#     'raw': 'Four guys three wearing hats one not are jumping at the top of a staircase.',
#     'imgid': 11,
#     'sentid': 57},
#    {'tokens': ['four',
#      'men',
#      'with',
#      'excited',
#      'faces',
#      'are',
#      'jumping',
#      'down',
#      'from',
#      'the',
#      'top',
#      'of',
#      'stairs'],
#     'raw': 'Four men with excited faces are jumping down from the top of stairs.',
#     'imgid': 11,
#     'sentid': 58},
#    {'tokens': ['four',
#      'people',
#      'are',
#      'jumping',
#      'from',
#      'the',
#      'top',
#      'of',
#      'a',
#      'flight',
#      'of',
#      'stairs'],
#     'raw': 'Four people are jumping from the top of a flight of stairs.',
#     'imgid': 11,
#     'sentid': 59}],
#   'split': 'train',
#   'filename': '1001633352.jpg'},
#  {'sentids': [60, 61, 62, 63, 64],
#   'imgid': 12,
#   'sentences': [{'tokens': ['a',
#      'black',
#      'dog',
#      'and',
#      'a',
#      'white',
#      'dog',
#      'with',
#      'brown',
#      'spots',
#      'are',
#      'staring',
#      'at',
#      'each',
#      'other',
#      'in',
#      'the',
#      'street'],
#     'raw': 'A black dog and a white dog with brown spots are staring at each other in the street.',
#     'imgid': 12,
#     'sentid': 60},
#    {'tokens': ['a',
#      'black',
#      'dog',
#      'and',
#      'a',
#      'tri',
#      'colored',
#      'dog',
#      'playing',
#      'with',
#      'each',
#      'other',
#      'on',
#      'the',
#      'road'],
#     'raw': 'A black dog and a tri-colored dog playing with each other on the road.',
#     'imgid': 12,
#     'sentid': 61},
#    {'tokens': ['two',
#      'dogs',
#      'of',
#      'different',
#      'breeds',
#      'looking',
#      'at',
#      'each',
#      'other',
#      'on',
#      'the',
#      'road'],
#     'raw': 'Two dogs of different breeds looking at each other on the road.',
#     'imgid': 12,
#     'sentid': 62},
#    {'tokens': ['two',
#      'dogs',
#      'on',
#      'pavement',
#      'moving',
#      'toward',
#      'each',
#      'other'],
#     'raw': 'Two dogs on pavement moving toward each other.',
#     'imgid': 12,
#     'sentid': 63},
#    {'tokens': ['a',
#      'black',
#      'dog',
#      'and',
#      'a',
#      'spotted',
#      'dog',
#      'are',
#      'fighting'],
#     'raw': 'A black dog and a spotted dog are fighting',
#     'imgid': 12,
#     'sentid': 64}],
#   'split': 'train',
#   'filename': '1001773457.jpg'},
#  {'sentids': [65, 66, 67, 68, 69],
#   'imgid': 13,
#   'sentences': [{'tokens': ['a',
#      'man',
#      'with',
#      'reflective',
#      'safety',
#      'clothes',
#      'and',
#      'ear',
#      'protection',
#      'drives',
#      'a',
#      'john',
#      'deere',
#      'tractor',
#      'on',
#      'a',
#      'road'],
#     'raw': 'A man with reflective safety clothes and ear protection drives a John Deere tractor on a road.',
#     'imgid': 13,
#     'sentid': 65},
#    {'tokens': ['john',
#      'deere',
#      'tractors',
#      'cruises',
#      'down',
#      'a',
#      'street',
#      'while',
#      'the',
#      'driver',
#      'wears',
#      'easy',
#      'to',
#      'see',
#      'clothing'],
#     'raw': 'John Deere tractors cruises down a street, while the driver wears easy to see clothing.',
#     'imgid': 13,
#     'sentid': 66},
#    {'tokens': ['a',
#      'man',
#      'in',
#      'a',
#      'neon',
#      'green',
#      'and',
#      'orange',
#      'uniform',
#      'is',
#      'driving',
#      'on',
#      'a',
#      'green',
#      'tractor'],
#     'raw': 'A man in a neon green and orange uniform is driving on a green tractor.',
#     'imgid': 13,
#     'sentid': 67},
#    {'tokens': ['a',
#      'man',
#      'in',
#      'a',
#      'tractor',
#      'wearing',
#      'headphones',
#      'driving',
#      'down',
#      'a',
#      'paved',
#      'street'],
#     'raw': 'A man in a tractor wearing headphones driving down a paved street.',
#     'imgid': 13,
#     'sentid': 68},
#    {'tokens': ['a',
#      'man',
#      'driving',
#      'a',
#      'john',
#      'deere',
#      'tractor',
#      'on',
#      'a',
#      'main',
#      'road',
#      'in',
#      'the',
#      'country'],
#     'raw': 'A man driving a John Deere tractor on a main road in the country.',
#     'imgid': 13,
#     'sentid': 69}],
#   'split': 'train',
#   'filename': '1001896054.jpg'},
#  {'sentids': [70, 71, 72, 73, 74],
#   'imgid': 14,
#   'sentences': [{'tokens': ['some',
#      'women',
#      'are',
#      'standing',
#      'in',
#      'front',
#      'of',
#      'a',
#      'bus',
#      'with',
#      'buildings',
#      'behind',
#      'it'],
#     'raw': 'Some women are standing in front of a bus with buildings behind it.',
#     'imgid': 14,
#     'sentid': 70},
#    {'tokens': ['several',
#      'women',
#      'stand',
#      'on',
#      'a',
#      'city',
#      'street',
#      'with',
#      'tall',
#      'buildings'],
#     'raw': 'Several women stand on a city street with tall buildings.',
#     'imgid': 14,
#     'sentid': 71},
#    {'tokens': ['a',
#      'group',
#      'of',
#      'women',
#      'are',
#      'standing',
#      'in',
#      'front',
#      'of',
#      'a',
#      'bus'],
#     'raw': 'A group of women are standing in front of a bus.',
#     'imgid': 14,
#     'sentid': 72},
#    {'tokens': ['several', 'women', 'wait', 'outside', 'in', 'a', 'city'],
#     'raw': 'Several women wait outside in a city.',
#     'imgid': 14,
#     'sentid': 73},
#    {'tokens': ['women', 'are', 'standing', 'outside'],
#     'raw': 'Women are standing outside',
#     'imgid': 14,
#     'sentid': 74}],
#   'split': 'train',
#   'filename': '100197432.jpg'},
#  {'sentids': [75, 76, 77, 78, 79],
#   'imgid': 15,
#   'sentences': [{'tokens': ['a',
#      'young',
#      'woman',
#      'with',
#      'dark',
#      'hair',
#      'and',
#      'wearing',
#      'glasses',
#      'is',
#      'putting',
#      'white',
#      'powder',
#      'on',
#      'a',
#      'cake',
#      'using',
#      'a',
#      'sifter'],
#     'raw': 'A young woman with dark hair and wearing glasses is putting white powder on a cake using a sifter.',
#     'imgid': 15,
#     'sentid': 75},
#    {'tokens': ['a',
#      'lady',
#      'in',
#      'a',
#      'black',
#      'top',
#      'with',
#      'glasses',
#      'is',
#      'sprinkling',
#      'powdered',
#      'sugar',
#      'on',
#      'a',
#      'bundt',
#      'cake'],
#     'raw': 'A lady in a black top with glasses is sprinkling powdered sugar on a bundt cake.',
#     'imgid': 15,
#     'sentid': 76},
#    {'tokens': ['a',
#      'woman',
#      'wearing',
#      'glasses',
#      'sprinkles',
#      'powdered',
#      'sugar',
#      'onto',
#      'her',
#      'bundt',
#      'cake'],
#     'raw': 'A woman wearing glasses sprinkles powdered sugar onto her bundt cake.',
#     'imgid': 15,
#     'sentid': 77},
#    {'tokens': ['girl',
#      'in',
#      'black',
#      'jacket',
#      'sifting',
#      'powdered',
#      'sugar',
#      'over',
#      'a',
#      'chocolate',
#      'cake'],
#     'raw': 'Girl in black jacket sifting powdered sugar over a chocolate cake.',
#     'imgid': 15,
#     'sentid': 78},
#    {'tokens': ['a',
#      'standing',
#      'woman',
#      'holds',
#      'a',
#      'pan',
#      'over',
#      'a',
#      'cake'],
#     'raw': 'A standing woman holds a pan over a cake.',
#     'imgid': 15,
#     'sentid': 79}],
#   'split': 'train',
#   'filename': '100207720.jpg'},
#  {'sentids': [80, 81, 82, 83, 84],
#   'imgid': 16,
#   'sentences': [{'tokens': ['a',
#      'small',
#      'girl',
#      'in',
#      'the',
#      'grass',
#      'plays',
#      'with',
#      'fingerpaints',
#      'in',
#      'front',
#      'of',
#      'a',
#      'white',
#      'canvas',
#      'with',
#      'a',
#      'rainbow',
#      'on',
#      'it'],
#     'raw': 'A small girl in the grass plays with fingerpaints in front of a white canvas with a rainbow on it.',
#     'imgid': 16,
#     'sentid': 80},
#    {'tokens': ['a',
#      'little',
#      'girl',
#      'covered',
#      'in',
#      'paint',
#      'sits',
#      'in',
#      'front',
#      'of',
#      'a',
#      'painted',
#      'rainbow',
#      'with',
#      'her',
#      'hands',
#      'in',
#      'a',
#      'bowl'],
#     'raw': 'A little girl covered in paint sits in front of a painted rainbow with her hands in a bowl.',
#     'imgid': 16,
#     'sentid': 81},
#    {'tokens': ['there',
#      'is',
#      'a',
#      'girl',
#      'with',
#      'pigtails',
#      'sitting',
#      'in',
#      'front',
#      'of',
#      'a',
#      'rainbow',
#      'painting'],
#     'raw': 'There is a girl with pigtails sitting in front of a rainbow painting.',
#     'imgid': 16,
#     'sentid': 82},
#    {'tokens': ['a',
#      'little',
#      'girl',
#      'is',
#      'sitting',
#      'in',
#      'front',
#      'of',
#      'a',
#      'large',
#      'painted',
#      'rainbow'],
#     'raw': 'A little girl is sitting in front of a large painted rainbow.',
#     'imgid': 16,
#     'sentid': 83},
#    {'tokens': ['young',
#      'girl',
#      'with',
#      'pigtails',
#      'painting',
#      'outside',
#      'in',
#      'the',
#      'grass'],
#     'raw': 'Young girl with pigtails painting outside in the grass.',
#     'imgid': 16,
#     'sentid': 84}],
#   'split': 'train',
#   'filename': '1002674143.jpg'},
#  {'sentids': [85, 86, 87, 88, 89],
#   'imgid': 17,
#   'sentences': [{'tokens': ['a',
#      'man',
#      'sleeping',
#      'on',
#      'a',
#      'bench',
#      'outside',
#      'with',
#      'a',
#      'white',
#      'and',
#      'black',
#      'dog',
#      'sitting',
#      'next',
#      'to',
#      'him'],
#     'raw': 'A man sleeping on a bench outside with a white and black dog sitting next to him.',
#     'imgid': 17,
#     'sentid': 85},
#    {'tokens': ['a',
#      'man',
#      'lays',
#      'on',
#      'the',
#      'bench',
#      'to',
#      'which',
#      'a',
#      'white',
#      'dog',
#      'is',
#      'also',
#      'tied'],
#     'raw': 'A man lays on the bench to which a white dog is also tied.',
#     'imgid': 17,
#     'sentid': 86},
#    {'tokens': ['man',
#      'laying',
#      'on',
#      'bench',
#      'holding',
#      'leash',
#      'of',
#      'dog',
#      'sitting',
#      'on',
#      'ground'],
#     'raw': 'Man laying on bench holding leash of dog sitting on ground',
#     'imgid': 17,
#     'sentid': 87},
#    {'tokens': ['a',
#      'shirtless',
#      'man',
#      'lies',
#      'on',
#      'a',
#      'park',
#      'bench',
#      'with',
#      'his',
#      'dog'],
#     'raw': 'A shirtless man lies on a park bench with his dog.',
#     'imgid': 17,
#     'sentid': 88},
#    {'tokens': ['a',
#      'man',
#      'lays',
#      'on',
#      'a',
#      'bench',
#      'while',
#      'his',
#      'dog',
#      'sits',
#      'by',
#      'him'],
#     'raw': 'A man lays on a bench while his dog sits by him.',
#     'imgid': 17,
#     'sentid': 89}],
#   'split': 'train',
#   'filename': '1003163366.jpg'},
#  {'sentids': [90, 91, 92, 93, 94],
#   'imgid': 18,
#   'sentences': [{'tokens': ['a',
#      'group',
#      'of',
#      'adults',
#      'inside',
#      'a',
#      'home',
#      'sitting',
#      'on',
#      'chairs',
#      'arranged',
#      'in',
#      'a',
#      'circle',
#      'playing',
#      'a',
#      'type',
#      'of',
#      'musical',
#      'instruments'],
#     'raw': 'A group of adults, inside a home, sitting on chairs arranged in a circle, playing a type of musical instruments.',
#     'imgid': 18,
#     'sentid': 90},
#    {'tokens': ['five',
#      'musicians',
#      'a',
#      'man',
#      'and',
#      'four',
#      'women',
#      'practicing',
#      'sheet',
#      'music',
#      '(using',
#      'flutes',
#      ')',
#      'in',
#      'a',
#      'living',
#      'room'],
#     'raw': 'Five musicians, a man and four women, practicing sheet music (using flutes ) in a living room.',
#     'imgid': 18,
#     'sentid': 91},
#    {'tokens': ['people',
#      'gathered',
#      'in',
#      'a',
#      'circle',
#      'some',
#      'holding',
#      'musical',
#      'instruments'],
#     'raw': 'People gathered in a circle, some holding musical instruments.',
#     'imgid': 18,
#     'sentid': 92},
#    {'tokens': ['people',
#      'gathered',
#      'in',
#      'a',
#      'room',
#      'to',
#      'talk',
#      'about',
#      'their',
#      'favorite',
#      'tunes'],
#     'raw': 'People gathered in a room to talk about their favorite tunes.',
#     'imgid': 18,
#     'sentid': 93},
#    {'tokens': ['five',
#      'people',
#      'are',
#      'sitting',
#      'in',
#      'a',
#      'circle',
#      'with',
#      'instruments'],
#     'raw': 'Five people are sitting in a circle with instruments.',
#     'imgid': 18,
#     'sentid': 94}],
#   'split': 'train',
#   'filename': '1003420127.jpg'},
#  {'sentids': [95, 96, 97, 98, 99],
#   'imgid': 19,
#   'sentences': [{'tokens': ['two',
#      'women',
#      'both',
#      'wearing',
#      'glasses',
#      'are',
#      'playing',
#      'clarinets',
#      'and',
#      'an',
#      'elderly',
#      'woman',
#      'is',
#      'playing',
#      'a',
#      'stringed',
#      'instrument'],
#     'raw': 'Two women, both wearing glasses, are playing clarinets and an elderly woman is playing a stringed instrument.',
#     'imgid': 19,
#     'sentid': 95},
#    {'tokens': ['at',
#      'least',
#      'four',
#      'instrumentalists',
#      'play',
#      'clarinets',
#      'and',
#      'other',
#      'instruments',
#      'in',
#      'a',
#      'curtained',
#      'room'],
#     'raw': 'At least four instrumentalists play clarinets and other instruments in a curtained room.',
#     'imgid': 19,
#     'sentid': 96},
#    {'tokens': ['four',
#      'women',
#      'in',
#      'a',
#      'living',
#      'room',
#      'three',
#      'of',
#      'which',
#      'are',
#      'clearly',
#      'playing',
#      'a',
#      'musical',
#      'instrument'],
#     'raw': 'Four women in a living room, three of which are clearly playing a musical instrument.',
#     'imgid': 19,
#     'sentid': 97},
#    {'tokens': ['a',
#      'bunch',
#      'of',
#      'elderly',
#      'women',
#      'play',
#      'their',
#      'clarinets',
#      'together',
#      'as',
#      'they',
#      'read',
#      'off',
#      'sheet',
#      'music'],
#     'raw': 'A bunch of elderly women play their clarinets together as they read off sheet music.',
#     'imgid': 19,
#     'sentid': 98},
#    {'tokens': ['a',
#      'group',
#      'of',
#      'four',
#      'women',
#      'are',
#      'performing',
#      'music',
#      'on',
#      'their',
#      'instruments'],
#     'raw': 'A group of four women, are performing music on their instruments.',
#     'imgid': 19,
#     'sentid': 99}],
#   'split': 'train',
#   'filename': '1003428081.jpg'},
#  {'sentids': [100, 101, 102, 103, 104],
#   'imgid': 20,
#   'sentences': [{'tokens': ['a',
#      'person',
#      'in',
#      'gray',
#      'stands',
#      'alone',
#      'on',
#      'a',
#      'structure',
#      'outdoors',
#      'in',
#      'the',
#      'dark'],
#     'raw': 'A person in gray stands alone on a structure outdoors in the dark.',
#     'imgid': 20,
#     'sentid': 100},
#    {'tokens': ['a',
#      'large',
#      'structure',
#      'has',
#      'broken',
#      'and',
#      'is',
#      'laying',
#      'in',
#      'a',
#      'roadway'],
#     'raw': 'A large structure has broken and is laying in a roadway.',
#     'imgid': 20,
#     'sentid': 101},
#    {'tokens': ['a',
#      'man',
#      'in',
#      'a',
#      'gray',
#      'coat',
#      'is',
#      'standing',
#      'on',
#      'a',
#      'washed',
#      'out',
#      'bridge'],
#     'raw': 'A man in a gray coat is standing on a washed out bridge.',
#     'imgid': 20,
#     'sentid': 102},
#    {'tokens': ['a',
#      'man',
#      'stands',
#      'on',
#      'wooden',
#      'supports',
#      'and',
#      'surveys',
#      'damage'],
#     'raw': 'A man stands on wooden supports and surveys damage.',
#     'imgid': 20,
#     'sentid': 103},
#    {'tokens': ['a',
#      'man',
#      'in',
#      'a',
#      'jacket',
#      'and',
#      'jeans',
#      'standing',
#      'on',
#      'a',
#      'bridge'],
#     'raw': 'A man in a jacket and jeans standing on a bridge.',
#     'imgid': 20,
#     'sentid': 104}],
#   'split': 'train',
#   'filename': '100444898.jpg'},
#  {'sentids': [105, 106, 107, 108, 109],
#   'imgid': 21,
#   'sentences': [{'tokens': ['a',
#      'man',
#      'in',
#      'a',
#      'white',
#      't',
#      'shirt',
#      'looks',
#      'toward',
#      'the',
#      'camera',
#      'surrounded',
#      'by',
#      'a',
#      'crowd',
#      'near',
#      'a',
#      'metro',
#      'station'],
#     'raw': 'A man in a white t-shirt looks toward the camera surrounded by a crowd near a metro station.',
#     'imgid': 21,
#     'sentid': 105},
#    {'tokens': ['a',
#      'large',
#      'crowd',
#      'of',
#      'people',
#      'stand',
#      'outside',
#      'in',
#      'front',
#      'of',
#      'the',
#      'entrance',
#      'to',
#      'a',
#      'metro',
#      'station'],
#     'raw': 'A large crowd of people stand outside in front of the entrance to a Metro station.',
#     'imgid': 21,
#     'sentid': 106},
#    {'tokens': ['a',
#      'group',
#      'of',
#      'people',
#      'are',
#      'walking',
#      'through',
#      'a',
#      'city',
#      'street'],
#     'raw': 'A group of people are walking through a city street.',
#     'imgid': 21,
#     'sentid': 107},
#    {'tokens': ['a',
#      'crowd',
#      'is',
#      'portrayed',
#      'near',
#      'a',
#      'metro',
#      'station'],
#     'raw': 'A crowd is portrayed near a metro station.',
#     'imgid': 21,
#     'sentid': 108},
#    {'tokens': ['crowd', 'standing', 'outside', 'a', 'metro', 'area'],
#     'raw': 'Crowd standing outside a metro area.',
#     'imgid': 21,
#     'sentid': 109}],
#   'split': 'train',
#   'filename': '1005216151.jpg'},
#  {'sentids': [110, 111, 112, 113, 114],
#   'imgid': 22,
#   'sentences': [{'tokens': ['a',
#      'man',
#      'with',
#      'a',
#      'goatee',
#      'in',
#      'a',
#      'black',
#      'shirt',
#      'and',
#      'white',
#      'latex',
#      'gloves',
#      'is',
#      'using',
#      'a',
#      'tattoo',
#      'gun',
#      'to',
#      'place',
#      'a',
#      'tattoo',
#      'on',
#      'someones',
#      'back'],
#     'raw': "A man with a goatee in a black shirt and white latex gloves is using a tattoo gun to place a tattoo on someone's back.",
#     'imgid': 22,
#     'sentid': 110},
#    {'tokens': ['a',
#      'man',
#      'is',
#      'putting',
#      'a',
#      'tattoo',
#      'on',
#      'a',
#      'anothers',
#      'man',
#      'upper',
#      'back'],
#     'raw': "A man is putting a tattoo on a another's man upper back.",
#     'imgid': 22,
#     'sentid': 111},
#    {'tokens': ['a',
#      'man',
#      'with',
#      'a',
#      'black',
#      'shirt',
#      'giving',
#      'another',
#      'man',
#      'a',
#      'tattoo'],
#     'raw': 'A man with a black shirt giving another man a tattoo.',
#     'imgid': 22,
#     'sentid': 112},
#    {'tokens': ['a', 'man', 'is', 'putting', 'tattoo', 'on', 'his', 'back'],
#     'raw': 'A man is putting tattoo on his back.',
#     'imgid': 22,
#     'sentid': 113},
#    {'tokens': ['a', 'man', 'getting', 'a', 'tattoo', 'on', 'his', 'back'],
#     'raw': 'A man getting a tattoo on his back.',
#     'imgid': 22,
#     'sentid': 114}],
#   'split': 'train',
#   'filename': '100577935.jpg'},
#  {'sentids': [115, 116, 117, 118, 119],
#   'imgid': 23,
#   'sentences': [{'tokens': ['two',
#      'children',
#      'a',
#      'girl',
#      'and',
#      'a',
#      'boy',
#      'are',
#      'practicing',
#      'their',
#      'writing'],
#     'raw': 'Two children, a girl and a boy are practicing their writing.',
#     'imgid': 23,
#     'sentid': 115},
#    {'tokens': ['two',
#      'children',
#      'sit',
#      'on',
#      'a',
#      'small',
#      'seesaw',
#      'in',
#      'the',
#      'sand'],
#     'raw': 'Two children sit on a small seesaw in the sand.',
#     'imgid': 23,
#     'sentid': 116},
#    {'tokens': ['two', 'children', 'sitting', 'on', 'a', 'teeter', 'totter'],
#     'raw': 'Two children sitting on a teeter totter.',
#     'imgid': 23,
#     'sentid': 117},
#    {'tokens': ['2', 'kids', 'playing', 'on', 'a', 'seesaw'],
#     'raw': '2 kids playing on a seesaw',
#     'imgid': 23,
#     'sentid': 118},
#    {'tokens': ['two', 'kids', 'sit', 'on', 'a', 'seesaw'],
#     'raw': 'Two kids sit on a seesaw.',
#     'imgid': 23,
#     'sentid': 119}],
#   'split': 'train',
#   'filename': '1006452823.jpg'},
#  {'sentids': [120, 121, 122, 123, 124],
#   'imgid': 24,
#   'sentences': [{'tokens': ['a',
#      'man',
#      'in',
#      'a',
#      'blue',
#      'hard',
#      'hat',
#      'and',
#      'orange',
#      'safety',
#      'vest',
#      'stands',
#      'in',
#      'an',
#      'intersection',
#      'while',
#      'holding',
#      'a',
#      'flag'],
#     'raw': 'A man in a blue hard hat and orange safety vest stands in an intersection while holding a flag.',
#     'imgid': 24,
#     'sentid': 120},
#    {'tokens': ['a',
#      'man',
#      'wearing',
#      'a',
#      'hard',
#      'hat',
#      'and',
#      'a',
#      'caution',
#      'vest',
#      'is',
#      'standing',
#      'in',
#      'the',
#      'street',
#      'waving',
#      'an',
#      'orange',
#      'flag'],
#     'raw': 'A man wearing a hard hat and a caution vest is standing in the street waving an orange flag.',
#     'imgid': 24,
#     'sentid': 121},
#    {'tokens': ['a',
#      'man',
#      'in',
#      'bright',
#      'vest',
#      'and',
#      'hard',
#      'hat',
#      'holds',
#      'a',
#      'flag',
#      'on',
#      'a',
#      'street',
#      'corner',
#      'covered',
#      'in',
#      'spray',
#      'paint'],
#     'raw': 'A man in bright vest and hard hat holds a flag on a street corner covered in spray paint',
#     'imgid': 24,
#     'sentid': 122},
#    {'tokens': ['a',
#      'construction',
#      'worker',
#      'is',
#      'standing',
#      'in',
#      'the',
#      'street',
#      'and',
#      'holding',
#      'a',
#      'red',
#      'flag'],
#     'raw': 'A construction worker is standing in the street and holding a red flag.',
#     'imgid': 24,
#     'sentid': 123},
#    {'tokens': ['a',
#      'man',
#      'wearing',
#      'a',
#      'reflective',
#      'vest',
#      'and',
#      'a',
#      'hard',
#      'hat',
#      'holds',
#      'a',
#      'flag',
#      'in',
#      'the',
#      'road'],
#     'raw': 'A man wearing a reflective vest and a hard hat holds a flag in the road',
#     'imgid': 24,
#     'sentid': 124}],
#   'split': 'train',
#   'filename': '100652400.jpg'},
#  {'sentids': [130, 131, 132, 133, 134],
#   'imgid': 26,
#   'sentences': [{'tokens': ['a',
#      'person',
#      'with',
#      'long',
#      'gray',
#      'hair',
#      'has',
#      'a',
#      'beret',
#      'with',
#      'beige',
#      'and',
#      'white',
#      'wearing',
#      'a',
#      'blue',
#      'raincoat',
#      'is',
#      'painting',
#      'a',
#      'marketplace',
#      'scenery',
#      'surrounded',
#      'by',
#      'other',
#      'artists',
#      'and',
#      'paintings'],
#     'raw': 'A person with long gray hair has a beret with beige and white wearing a blue raincoat is painting a marketplace scenery surrounded by other artists and paintings.',
#     'imgid': 26,
#     'sentid': 130},
#    {'tokens': ['a',
#      'person',
#      'dressed',
#      'in',
#      'a',
#      'blue',
#      'coat',
#      'is',
#      'standing',
#      'in',
#      'on',
#      'a',
#      'busy',
#      'sidewalk',
#      'studying',
#      'painting',
#      'of',
#      'a',
#      'street',
#      'scene'],
#     'raw': 'A person dressed in a blue coat is standing in on a busy sidewalk, studying painting of a street scene.',
#     'imgid': 26,
#     'sentid': 131},
#    {'tokens': ['a',
#      'person',
#      'with',
#      'gray',
#      'hair',
#      'is',
#      'painting',
#      'in',
#      'a',
#      'public',
#      'place',
#      'surrounded',
#      'by',
#      'others',
#      'who',
#      'are',
#      'also',
#      'painting'],
#     'raw': 'A person with gray hair is painting in a public place surrounded by others who are also painting.',
#     'imgid': 26,
#     'sentid': 132},
#    {'tokens': ['lady',
#      'in',
#      'blue',
#      'coat',
#      'with',
#      'white',
#      'and',
#      'brown',
#      'hat',
#      'standing',
#      'in',
#      'front',
#      'of',
#      'a',
#      'painting'],
#     'raw': 'Lady in blue coat with white and brown hat standing in front of a painting.',
#     'imgid': 26,
#     'sentid': 133},
#    {'tokens': ['passerby',
#      'admiring',
#      'painting',
#      'at',
#      'an',
#      'outdoor',
#      'art',
#      'fair'],
#     'raw': 'Passerby admiring painting at an outdoor art fair.',
#     'imgid': 26,
#     'sentid': 134}],
#   'split': 'train',
#   'filename': '100716317.jpg'},
#  {'sentids': [135, 136, 137, 138, 139],
#   'imgid': 27,
#   'sentences': [{'tokens': ['a',
#      'man',
#      'stands',
#      'on',
#      'one',
#      'foot',
#      'while',
#      'holding',
#      'on',
#      'to',
#      'a',
#      'waste',
#      'basket'],
#     'raw': 'A man stands on one foot while holding on to a waste basket.',
#     'imgid': 27,
#     'sentid': 135},
#    {'tokens': ['a',
#      'man',
#      'in',
#      'green',
#      'pants',
#      'and',
#      'blue',
#      'shirt',
#      'pushing',
#      'a',
#      'cart'],
#     'raw': 'A man in green pants and blue shirt pushing a cart.',
#     'imgid': 27,
#     'sentid': 136},
#    {'tokens': ['janitor',
#      'pushing',
#      'dolly',
#      'outside',
#      'with',
#      'janitor',
#      'tools'],
#     'raw': 'Janitor pushing dolly outside with janitor tools.',
#     'imgid': 27,
#     'sentid': 137},
#    {'tokens': ['a',
#      'man',
#      'in',
#      'green',
#      'pants',
#      'walking',
#      'down',
#      'the',
#      'road'],
#     'raw': 'A man in green pants walking down the road.',
#     'imgid': 27,
#     'sentid': 138},
#    {'tokens': ['a',
#      'man',
#      'in',
#      'bright',
#      'pants',
#      'is',
#      'pushing',
#      'a',
#      'cart'],
#     'raw': 'A man in bright pants is pushing a cart.',
#     'imgid': 27,
#     'sentid': 139}],
#   'split': 'train',
#   'filename': '1007205537.jpg'},
#  {'sentids': [140, 141, 142, 143, 144],
#   'imgid': 28,
#   'sentences': [{'tokens': ['a',
#      'small',
#      'child',
#      'grips',
#      'onto',
#      'the',
#      'red',
#      'ropes',
#      'at',
#      'the',
#      'playground'],
#     'raw': 'A small child grips onto the red ropes at the playground.',
#     'imgid': 28,
#     'sentid': 140},
#    {'tokens': ['a',
#      'little',
#      'girl',
#      'in',
#      'pink',
#      'climbs',
#      'a',
#      'rope',
#      'bridge',
#      'at',
#      'the',
#      'park'],
#     'raw': 'A little girl in pink climbs a rope bridge at the park.',
#     'imgid': 28,
#     'sentid': 141},
#    {'tokens': ['the',
#      'small',
#      'child',
#      'climbs',
#      'on',
#      'a',
#      'red',
#      'ropes',
#      'on',
#      'a',
#      'playground'],
#     'raw': 'The small child climbs on a red ropes on a playground.',
#     'imgid': 28,
#     'sentid': 142},
#    {'tokens': ['a', 'little', 'girl', 'climbing', 'on', 'red', 'roping'],
#     'raw': 'A little girl climbing on red roping.',
#     'imgid': 28,
#     'sentid': 143},
#    {'tokens': ['a', 'child', 'playing', 'on', 'a', 'rope', 'net'],
#     'raw': 'A child playing on a rope net.',
#     'imgid': 28,
#     'sentid': 144}],
#   'split': 'train',
#   'filename': '1007320043.jpg'},
#  {'sentids': [145, 146, 147, 148, 149],
#   'imgid': 29,
#   'sentences': [{'tokens': ['young',
#      'man',
#      'in',
#      'jacket',
#      'holding',
#      'a',
#      'toothpick',
#      'with',
#      'something',
#      'on',
#      'the',
#      'end',
#      'of',
#      'it'],
#     'raw': 'Young man in jacket holding a toothpick with something on the end of it',
#     'imgid': 29,
#     'sentid': 145},
#    {'tokens': ['a',
#      'young',
#      'man',
#      'traveling',
#      'on',
#      'bus',
#      'with',
#      'a',
#      'piece',
#      'of',
#      'flower',
#      'in',
#      'his',
#      'hands'],
#     'raw': 'A young man traveling on bus with a piece of flower in his hands.',
#     'imgid': 29,
#     'sentid': 146},
#    {'tokens': ['a',
#      'teen',
#      'holding',
#      'an',
#      'unknown',
#      'object',
#      'for',
#      'photographers'],
#     'raw': 'A teen holding an unknown object for photographers.',
#     'imgid': 29,
#     'sentid': 147},
#    {'tokens': ['a',
#      'young',
#      'man',
#      'on',
#      'a',
#      'train',
#      'holds',
#      'an',
#      'origami',
#      'crane'],
#     'raw': 'A young man on a train holds an origami crane.',
#     'imgid': 29,
#     'sentid': 148},
#    {'tokens': ['you',
#      'know',
#      'i',
#      'am',
#      'looking',
#      'like',
#      'justin',
#      'bieber'],
#     'raw': 'You know i am looking like Justin Bieber.',
#     'imgid': 29,
#     'sentid': 149}],
#   'split': 'train',
#   'filename': '100759042.jpg'},
#  {'sentids': [150, 151, 152, 153, 154],
#   'imgid': 30,
#   'sentences': [{'tokens': ['young',
#      'blond',
#      'man',
#      'in',
#      'a',
#      'blue',
#      'and',
#      'yellow',
#      'jacket',
#      'smiling',
#      'while',
#      'standing',
#      'in',
#      'front',
#      'of',
#      'a',
#      'net'],
#     'raw': 'Young blond man in a blue and yellow jacket smiling while standing in front of a net.',
#     'imgid': 30,
#     'sentid': 150},
#    {'tokens': ['a',
#      'young',
#      'man',
#      'in',
#      'a',
#      'black',
#      'and',
#      'yellow',
#      'jacket',
#      'is',
#      'gazing',
#      'at',
#      'something',
#      'and',
#      'smiling'],
#     'raw': 'A young man in a black and yellow jacket is gazing at something and smiling.',
#     'imgid': 30,
#     'sentid': 151},
#    {'tokens': ['a',
#      'young',
#      'man',
#      'holding',
#      'a',
#      'pole',
#      'vault',
#      'looks',
#      'determined'],
#     'raw': 'A young man holding a pole vault looks determined.',
#     'imgid': 30,
#     'sentid': 152},
#    {'tokens': ['a', 'man', 'is', 'holding', 'a', 'pole', 'and', 'smiling'],
#     'raw': 'A man is holding a pole and smiling.',
#     'imgid': 30,
#     'sentid': 153},
#    {'tokens': ['a', 'smiling', 'man', 'looking', 'at', 'the', 'sky'],
#     'raw': 'A smiling man looking at the sky.',
#     'imgid': 30,
#     'sentid': 154}],
#   'split': 'train',
#   'filename': '10082347.jpg'},
#  {'sentids': [155, 156, 157, 158, 159],
#   'imgid': 31,
#   'sentences': [{'tokens': ['a',
#      'man',
#      'with',
#      'a',
#      'baseball',
#      'cap',
#      'and',
#      'black',
#      'jacket',
#      'stands',
#      'in',
#      'a',
#      'bathroom',
#      'while',
#      'holding',
#      'a',
#      'coffee',
#      'mug'],
#     'raw': 'A man with a baseball cap and black jacket stands in a bathroom while holding a coffee mug.',
#     'imgid': 31,
#     'sentid': 155},
#    {'tokens': ['a',
#      'man',
#      'is',
#      'wearing',
#      'a',
#      'ball',
#      'cap',
#      'and',
#      'holding',
#      'a',
#      'coffee',
#      'cup',
#      'between',
#      'to',
#      'urinals'],
#     'raw': 'A man is wearing a ball cap and holding a coffee cup between to urinals.',
#     'imgid': 31,
#     'sentid': 156},
#    {'tokens': ['a',
#      'man',
#      'is',
#      'posing',
#      'next',
#      'to',
#      'a',
#      'urinal',
#      'with',
#      'a',
#      'cup',
#      'of',
#      'coffee'],
#     'raw': 'A man is posing next to a urinal with a cup of coffee.',
#     'imgid': 31,
#     'sentid': 157},
#    {'tokens': ['a',
#      'man',
#      'holds',
#      'a',
#      'coffee',
#      'cup',
#      'while',
#      'in',
#      'the',
#      'bathroom'],
#     'raw': 'A man holds a coffee cup while in the bathroom.',
#     'imgid': 31,
#     'sentid': 158},
#    {'tokens': ['a',
#      'man',
#      'standing',
#      'at',
#      'a',
#      'urinal',
#      'with',
#      'a',
#      'coffee',
#      'cup'],
#     'raw': 'A man standing at a urinal with a coffee cup.',
#     'imgid': 31,
#     'sentid': 159}],
#   'split': 'train',
#   'filename': '10082348.jpg'},
#  {'sentids': [160, 161, 162, 163, 164],
#   'imgid': 32,
#   'sentences': [{'tokens': ['five',
#      'people',
#      'walking',
#      'with',
#      'a',
#      'multicolored',
#      'sky',
#      'in',
#      'the',
#      'background'],
#     'raw': 'Five people walking with a multicolored sky in the background.',
#     'imgid': 32,
#     'sentid': 160},
#    {'tokens': ['four',
#      'people',
#      'walking',
#      'through',
#      'the',
#      'sunset',
#      'in',
#      'clear',
#      'blue',
#      'skies'],
#     'raw': 'Four people walking through the sunset in clear blue skies.',
#     'imgid': 32,
#     'sentid': 161},
#    {'tokens': ['four',
#      'people',
#      'walking',
#      'with',
#      'the',
#      'sun',
#      'setting',
#      'behind',
#      'them'],
#     'raw': 'Four people walking with the sun setting behind them.',
#     'imgid': 32,
#     'sentid': 162},
#    {'tokens': ['four', 'silhouettes', 'decorate', 'the', 'horizons', 'sunset'],
#     'raw': "Four silhouettes decorate the horizon's sunset.",
#     'imgid': 32,
#     'sentid': 163},
#    {'tokens': ['a',
#      'group',
#      'of',
#      'people',
#      'walking',
#      'as',
#      'the',
#      'sun',
#      'sets'],
#     'raw': 'A group of people walking as the sun sets.',
#     'imgid': 32,
#     'sentid': 164}],
#   'split': 'train',
#   'filename': '100845130.jpg'},
#  {'sentids': [165, 166, 167, 168, 169],
#   'imgid': 33,
#   'sentences': [{'tokens': ['a',
#      'man',
#      'with',
#      'black',
#      'hair',
#      'sits',
#      'in',
#      'a',
#      'restaurant',
#      'with',
#      'a',
#      'glass',
#      'of',
#      'beer'],
#     'raw': 'A man with black hair sits in a restaurant with a glass of beer.',
#     'imgid': 33,
#     'sentid': 165},
#    {'tokens': ['a',
#      'man',
#      'is',
# ...
#     'raw': 'A small child with a bike outside of a shop',
#     'imgid': 1071,
#     'sentid': 5358},
#    {'tokens': ['a',
#      'boy',
#      'is',
#      'sitting',
#      'by',
#      'a',
#      'bike',
#      'by',
#      'a',
#      'hotel'],
#     'raw': 'A boy is sitting by a bike, by a hotel.',
#     'imgid': 1071,
#     'sentid': 5359}],
#   'split': 'train',
#   'filename': '1339866098.jpg'},
#  {'sentids': [5365, 5366, 5367, 5368, 5369],
#   'imgid': 1073,
#   'sentences': [{'tokens': ['2',
#      'people',
#      'one',
#      'wearing',
#      'a',
#      'blue',
#      'shirt',
#      'the',
#      'other',
#      'orange',
#      'taking',
#      'a',
#      'bike',
#      'ride',
#      'in',
#      'the',
#      'country',
#      'with',
#      'a',
#      'beautiful',
#      'orange',
#      'sunset',
#      'behind',
#      'them'],
#     'raw': '2 people one wearing a blue shirt the other orange taking a bike ride in the country with a beautiful orange sunset behind them.',
#     'imgid': 1073,
#     'sentid': 5365},
#    {'tokens': ['two',
#      'bikers',
#      'riding',
#      'towards',
#      'you',
#      'with',
#      'the',
#      'sun',
#      'setting',
#      'or',
#      'rising',
#      'in',
#      'the',
#      'background'],
#     'raw': 'Two bikers riding towards you with the sun setting or rising in the background.',
#     'imgid': 1073,
#     'sentid': 5366},
#    {'tokens': ['two',
#      'people',
#      'are',
#      'riding',
#      'their',
#      'bikes',
#      'on',
#      'a',
#      'country',
#      'road',
#      'as',
#      'the',
#      'sun',
#      'is',
#      'rising'],
#     'raw': 'Two people are riding their bikes on a country road as the sun is rising.',
#     'imgid': 1073,
#     'sentid': 5367},
#    {'tokens': ['the',
#      'sunshine',
#      'behind',
#      'a',
#      'group',
#      'of',
#      'trees',
#      'on',
#      'a',
#      'long',
#      'rode'],
#     'raw': 'The sunshine behind a group of trees on a long rode.',
#     'imgid': 1073,
#     'sentid': 5368},
#    {'tokens': ['2', 'people', 'riding', 'bikes', 'during', 'a', 'sunset'],
#     'raw': '2 people riding bikes during a sunset.',
#     'imgid': 1073,
#     'sentid': 5369}],
#   'split': 'train',
#   'filename': '1341529446.jpg'},
#  {'sentids': [5375, 5376, 5377, 5378, 5379],
#   'imgid': 1075,
#   'sentences': [{'tokens': ['a',
#      'man',
#      'wearing',
#      'a',
#      'get',
#      'a',
#      'job',
#      't',
#      'shirt',
#      'takes',
#      'a',
#      'picture',
#      'of',
#      'the',
#      'camera',
#      'holder',
#      'with',
#      'a',
#      'bright',
#      'yellow',
#      'camera',
#      'while',
#      'also',
#      'holding',
#      'a',
#      'photo',
#      'in',
#      'his',
#      'left',
#      'hand'],
#     'raw': 'A man wearing a Get A Job t-shirt takes a picture of the camera holder with a bright yellow camera while also holding a photo in his left hand.',
#     'imgid': 1075,
#     'sentid': 5375},
#    {'tokens': ['a',
#      'man',
#      'wearing',
#      'an',
#      'orange',
#      'shirt',
#      'takes',
#      'a',
#      'photograph'],
#     'raw': 'A man wearing an orange shirt takes a photograph',
#     'imgid': 1075,
#     'sentid': 5376},
#    {'tokens': ['a',
#      'man',
#      'in',
#      'an',
#      'orange',
#      'shirt',
#      'is',
#      'taking',
#      'a',
#      'picture'],
#     'raw': 'A man in an orange shirt is taking a picture.',
#     'imgid': 1075,
#     'sentid': 5377},
#    {'tokens': ['a',
#      'man',
#      'taking',
#      'a',
#      'photograph',
#      'holding',
#      'a',
#      'postcard'],
#     'raw': 'A man taking a photograph, holding a postcard',
#     'imgid': 1075,
#     'sentid': 5378},
#    {'tokens': ['a', 'person', 'holding', 'a', 'yellow', 'camera'],
#     'raw': 'A person holding a yellow camera.',
#     'imgid': 1075,
#     'sentid': 5379}],
#   'split': 'train',
#   'filename': '134201079.jpg'},
#  {'sentids': [5380, 5381, 5382, 5383, 5384],
#   'imgid': 1076,
#   'sentences': [{'tokens': ['the',
#      'players',
#      'of',
#      'the',
#      'baseball',
#      'team',
#      'are',
#      'standing',
#      'on',
#      'the',
#      'field',
#      'with',
#      'many',
#      'people',
#      'watching',
#      'from',
#      'the',
#      'stands'],
#     'raw': 'The players of the baseball team are standing on the field, with many people watching from the stands.',
#     'imgid': 1076,
#     'sentid': 5380},
#    {'tokens': ['baseball',
#      'players',
#      'are',
#      'playing',
#      'on',
#      'a',
#      'field',
#      'in',
#      'a',
#      'stadium',
#      'filled',
#      'with',
#      'people'],
#     'raw': 'Baseball players are playing on a field in a stadium filled with people.',
#     'imgid': 1076,
#     'sentid': 5381},
#    {'tokens': ['a',
#      'team',
#      'plays',
#      'baseball',
#      'at',
#      'a',
#      'large',
#      'crowded',
#      'stadium'],
#     'raw': 'A team plays baseball at a large crowded stadium.',
#     'imgid': 1076,
#     'sentid': 5382},
#    {'tokens': ['a', 'crowd', 'cheers', 'on', 'a', 'baseball', 'team'],
#     'raw': 'A crowd cheers on a baseball team.',
#     'imgid': 1076,
#     'sentid': 5383},
#    {'tokens': ['game', 'is', 'playing', 'in', 'the', 'stadium'],
#     'raw': 'Game is playing in the stadium',
#     'imgid': 1076,
#     'sentid': 5384}],
#   'split': 'train',
#   'filename': '134206.jpg'},
#  {'sentids': [5385, 5386, 5387, 5388, 5389],
#   'imgid': 1077,
#   'sentences': [{'tokens': ['a',
#      'young',
#      'boy',
#      'in',
#      'a',
#      'red',
#      'shirt',
#      'and',
#      'his',
#      'older',
#      'friend',
#      'are',
#      'heading',
#      'down',
#      'a',
#      'heavily',
#      'wooded',
#      'trail'],
#     'raw': 'A young boy in a red shirt and his older friend are heading down a heavily-wooded trail.',
#     'imgid': 1077,
#     'sentid': 5385},
#    {'tokens': ['a',
#      'man',
#      'and',
#      'a',
#      'much',
#      'younger',
#      'boy',
#      'both',
#      'wearing',
#      'hats',
#      'taking',
#      'a',
#      'stroll',
#      'through',
#      'nature'],
#     'raw': 'A man and a much younger boy, both wearing hats, taking a stroll through nature.',
#     'imgid': 1077,
#     'sentid': 5386},
#    {'tokens': ['two',
#      'children',
#      'walk',
#      'down',
#      'a',
#      'path',
#      'into',
#      'the',
#      'woods'],
#     'raw': 'Two children walk down a path into the woods.',
#     'imgid': 1077,
#     'sentid': 5387},
#    {'tokens': ['man',
#      'and',
#      'child',
#      'in',
#      'hats',
#      'walk',
#      'on',
#      'a',
#      'dirt',
#      'trail'],
#     'raw': 'Man and child in hats walk on a dirt trail.',
#     'imgid': 1077,
#     'sentid': 5388},
#    {'tokens': ['a', 'father', 'and', 'son', 'hiking', 'in', 'the', 'woods'],
#     'raw': 'A father and son hiking in the woods.',
#     'imgid': 1077,
#     'sentid': 5389}],
#   'split': 'train',
#   'filename': '1342407554.jpg'},
#  {'sentids': [5390, 5391, 5392, 5393, 5394],
#   'imgid': 1078,
#   'sentences': [{'tokens': ['one',
#      'small',
#      'boy',
#      'climbing',
#      'a',
#      'pole',
#      'with',
#      'the',
#      'help',
#      'of',
#      'another',
#      'boy',
#      'on',
#      'the',
#      'ground'],
#     'raw': 'One small boy climbing a pole with the help of another boy on the ground',
#     'imgid': 1078,
#     'sentid': 5390},
#    {'tokens': ['one',
#      'boy',
#      'is',
#      'helping',
#      'another',
#      'boy',
#      'to',
#      'climb',
#      'a',
#      'green',
#      'pole',
#      'in',
#      'the',
#      'street'],
#     'raw': 'One boy is helping another boy to climb a green pole in the street.',
#     'imgid': 1078,
#     'sentid': 5391},
#    {'tokens': ['little',
#      'boy',
#      'pushing',
#      'another',
#      'little',
#      'boy',
#      'up',
#      'the',
#      'pole'],
#     'raw': 'Little boy pushing another little boy up the pole.',
#     'imgid': 1078,
#     'sentid': 5392},
#    {'tokens': ['the',
#      'boy',
#      'is',
#      'trying',
#      'to',
#      'push',
#      'another',
#      'up',
#      'a',
#      'pole'],
#     'raw': 'The boy is trying to push another up a pole.',
#     'imgid': 1078,
#     'sentid': 5393},
#    {'tokens': ['a', 'boy', 'pushing', 'another', 'boy', 'up', 'a', 'pole'],
#     'raw': 'A boy pushing another boy up a pole.',
#     'imgid': 1078,
#     'sentid': 5394}],
#   'split': 'train',
#   'filename': '1342766791.jpg'},
#  {'sentids': [5395, 5396, 5397, 5398, 5399],
#   'imgid': 1079,
#   'sentences': [{'tokens': ['a',
#      'man',
#      'with',
#      'a',
#      'white',
#      'shirt',
#      'and',
#      'tie',
#      'is',
#      'standing',
#      'on',
#      'a',
#      'sidewalk',
#      'between',
#      'cement',
#      'barriers'],
#     'raw': 'A man with a white shirt and tie is standing on a sidewalk between cement barriers.',
#     'imgid': 1079,
#     'sentid': 5395},
#    {'tokens': ['a',
#      'man',
#      'in',
#      'a',
#      'dress',
#      'shirt',
#      'and',
#      'tie',
#      'is',
#      'standing',
#      'in',
#      'front',
#      'of',
#      'a',
#      'sign',
#      'selling',
#      'donuts'],
#     'raw': 'A man in a dress shirt and tie is standing in front of a sign selling donuts.',
#     'imgid': 1079,
#     'sentid': 5396},
#    {'tokens': ['a',
#      'man',
#      'stands',
#      'among',
#      'cement',
#      'fixtures',
#      'in',
#      'front',
#      'of',
#      'a',
#      'donut',
#      'shop'],
#     'raw': 'A man stands among cement fixtures in front of a donut shop.',
#     'imgid': 1079,
#     'sentid': 5397},
#    {'tokens': ['man',
#      'stands',
#      'between',
#      'concrete',
#      'barriers',
#      'near',
#      'a',
#      'donut',
#      'shop'],
#     'raw': 'Man stands between concrete barriers near a donut shop.',
#     'imgid': 1079,
#     'sentid': 5398},
#    {'tokens': ['a', 'well', 'dressed', 'man', 'in', 'the', 'street'],
#     'raw': 'A well-dressed man in the street.',
#     'imgid': 1079,
#     'sentid': 5399}],
#   'split': 'train',
#   'filename': '1342780478.jpg'},
#  {'sentids': [5400, 5401, 5402, 5403, 5404],
#   'imgid': 1080,
#   'sentences': [{'tokens': ['an',
#      'individual',
#      'is',
#      'climbing',
#      'on',
#      'an',
#      'objects',
#      'while',
#      'the',
#      'bottom',
#      'of',
#      'his',
#      'shoes',
#      'can',
#      'be',
#      'seen'],
#     'raw': 'An individual is climbing on an objects while the bottom of his shoes can be seen.',
#     'imgid': 1080,
#     'sentid': 5400},
#    {'tokens': ['a',
#      'man',
#      'wearing',
#      'black',
#      'jeans',
#      'and',
#      'skater',
#      'shoes',
#      'climbs',
#      'a',
#      'jungle',
#      'gym'],
#     'raw': 'A man wearing black jeans and skater shoes climbs a jungle gym.',
#     'imgid': 1080,
#     'sentid': 5401},
#    {'tokens': ['a',
#      'child',
#      'climbing',
#      'to',
#      'the',
#      'top',
#      'of',
#      'a',
#      'jungle',
#      'gym'],
#     'raw': 'A child climbing to the top of a jungle gym.',
#     'imgid': 1080,
#     'sentid': 5402},
#    {'tokens': ['a',
#      'boy',
#      'reaches',
#      'the',
#      'top',
#      'of',
#      'a',
#      'jungle',
#      'gym'],
#     'raw': 'A boy reaches the top of a jungle gym.',
#     'imgid': 1080,
#     'sentid': 5403},
#    {'tokens': ['a', 'boy', 'with', 'blue', 'jeans', 'is', 'climbing'],
#     'raw': 'A boy with blue jeans is climbing.',
#     'imgid': 1080,
#     'sentid': 5404}],
#   'split': 'train',
#   'filename': '134283905.jpg'},
#  {'sentids': [5410, 5411, 5412, 5413, 5414],
#   'imgid': 1082,
#   'sentences': [{'tokens': ['young',
#      'children',
#      'practicing',
#      'karate',
#      'are',
#      'organized',
#      'in',
#      'a',
#      'gymnasium',
#      'facing',
#      'the',
#      'american',
#      'flag',
#      'being',
#      'watched',
#      'by',
#      'adults',
#      'in',
#      'black',
#      'and',
#      'yellow',
#      'karate',
#      'outfits'],
#     'raw': 'Young children practicing karate are organized in a gymnasium facing the American flag, being watched by adults in black and yellow karate outfits.',
#     'imgid': 1082,
#     'sentid': 5410},
#    {'tokens': ['two',
#      'people',
#      'in',
#      'black',
#      'vests',
#      'are',
#      'standing',
#      'in',
#      'front',
#      'of',
#      'children',
#      'in',
#      'white',
#      'vests',
#      'with',
#      'an',
#      'american',
#      'flag',
#      'between',
#      'them'],
#     'raw': 'Two people in black vests are standing in front of children in white vests with an American flag between them.',
#     'imgid': 1082,
#     'sentid': 5411},
#    {'tokens': ['a',
#      'group',
#      'of',
#      'children',
#      'wearing',
#      'white',
#      'karate',
#      'shirts',
#      'looking',
#      'at',
#      'the',
#      'american',
#      'flag'],
#     'raw': 'A group of children, wearing white karate shirts, looking at the American flag.',
#     'imgid': 1082,
#     'sentid': 5412},
#    {'tokens': ['crowd',
#      'of',
#      'children',
#      'presenting',
#      'the',
#      'american',
#      'flag',
#      'what',
#      'looks',
#      'like',
#      'their',
#      'teachers'],
#     'raw': 'Crowd of children presenting the American flag what looks like their teachers.',
#     'imgid': 1082,
#     'sentid': 5413},
#    {'tokens': ['people', 'on', 'a', 'karate', 'ceremony'],
#     'raw': 'People on a karate ceremony.',
#     'imgid': 1082,
#     'sentid': 5414}],
#   'split': 'train',
#   'filename': '1343787097.jpg'},
#  {'sentids': [5415, 5416, 5417, 5418, 5419],
#   'imgid': 1083,
#   'sentences': [{'tokens': ['in',
#      'a',
#      'martial',
#      'arts',
#      'demonstration',
#      'a',
#      'man',
#      'with',
#      'two',
#      'swords',
#      'faces',
#      'a',
#      'woman',
#      'with',
#      'a',
#      'chinese',
#      'spear'],
#     'raw': 'In a martial arts demonstration a man with two swords faces a woman with a Chinese spear.',
#     'imgid': 1083,
#     'sentid': 5415},
#    {'tokens': ['two',
#      'people',
#      'a',
#      'man',
#      'and',
#      'a',
#      'woman',
#      'on',
#      'stage',
#      'demonstration',
#      'the',
#      'martial',
#      'arts',
#      'to',
#      'a',
#      'crowd'],
#     'raw': 'Two people a man and a woman on stage demonstration the martial arts to a crowd.',
#     'imgid': 1083,
#     'sentid': 5416},
#    {'tokens': ['two',
#      'martial',
#      'artists',
#      'face',
#      'off',
#      'one',
#      'holding',
#      'swords',
#      'the',
#      'other',
#      'holding',
#      'a',
#      'spear'],
#     'raw': 'Two martial artists face off - one holding swords, the other holding a spear.',
#     'imgid': 1083,
#     'sentid': 5417},
#    {'tokens': ['a',
#      'competition',
#      'match',
#      'between',
#      'two',
#      'martial',
#      'arts',
#      'fighters'],
#     'raw': 'A competition match between two martial arts fighters.',
#     'imgid': 1083,
#     'sentid': 5418},
#    {'tokens': ['a',
#      'man',
#      'with',
#      'swords',
#      'battling',
#      'a',
#      'female',
#      'with',
#      'a',
#      'spear'],
#     'raw': 'A man with swords battling a female with a spear.',
#     'imgid': 1083,
#     'sentid': 5419}],
#   'split': 'train',
#   'filename': '1344692842.jpg'},
#  {'sentids': [5420, 5421, 5422, 5423, 5424],
#   'imgid': 1084,
#   'sentences': [{'tokens': ['two',
#      'boxers',
#      'wearing',
#      'protective',
#      'gear',
#      'are',
#      'fighting',
#      'with',
#      'onlookers',
#      'watching'],
#     'raw': 'Two boxers wearing protective gear are fighting, with onlookers watching.',
#     'imgid': 1084,
#     'sentid': 5420},
#    {'tokens': ['two',
#      'well',
#      'padded',
#      'boxers',
#      'face',
#      'off',
#      'in',
#      'a',
#      'high',
#      'school',
#      'gym',
#      'as',
#      'people',
#      'watch'],
#     'raw': 'Two well padded boxers face off in a high school gym as people watch.',
#     'imgid': 1084,
#     'sentid': 5421},
#    {'tokens': ['two',
#      'men',
#      'are',
#      'in',
#      'a',
#      'boxing',
#      'match',
#      'with',
#      'an',
#      'audience',
#      'watching'],
#     'raw': 'Two men are in a boxing match, with an audience watching.',
#     'imgid': 1084,
#     'sentid': 5422},
#    {'tokens': ['two',
#      'men',
#      'in',
#      'the',
#      'middle',
#      'of',
#      'the',
#      'action',
#      'of',
#      'a',
#      'fighting',
#      'match'],
#     'raw': 'Two men in the middle of the action of a fighting match.',
#     'imgid': 1084,
#     'sentid': 5423},
#    {'tokens': ['two',
#      'men',
#      'wearing',
#      'boxing',
#      'gear',
#      'and',
#      'engaging',
#      'in',
#      'a',
#      'match'],
#     'raw': 'Two men wearing boxing gear and engaging in a match.',
#     'imgid': 1084,
#     'sentid': 5424}],
#   'split': 'train',
#   'filename': '1344701234.jpg'},
#  ...]

# %%
import os
output_dir = data_path + '/train'
os.makedirs(output_dir, exist_ok=True)

# %%
from PIL import Image

input_dir = data_path + '/imgs'
for img_info in train_data:
    filename = img_info['filename']
    img = Image.open(input_dir + '/' + filename)
    img.save(output_dir + '/' + filename)

# %%
output_dir = data_path + '/validation'
os.makedirs(output_dir, exist_ok=True)

input_dir = data_path + '/imgs'
for img_info in val_data:
    filename = img_info['filename']
    img = Image.open(input_dir + '/' + filename)
    img.save(output_dir + '/' + filename)

# %%
output_dir = data_path + '/test'
os.makedirs(output_dir, exist_ok=True)

input_dir = data_path + '/imgs'
for img_info in test_data:
    filename = img_info['filename']
    img = Image.open(input_dir + '/' + filename)
    img.save(output_dir + '/' + filename)

# %%
for ii, key in enumerate(train_data):
    for j, sentence in enumerate(key['sentences']):
        print("{}, {}".format(ii,sentence['raw']))
    if ii == 10:
        break
# Out:
# 0, Two young guys with shaggy hair look at their hands while hanging out in the yard.
# 0, Two young, White males are outside near many bushes.
# 0, Two men in green shirts are standing in a yard.
# 0, A man in a blue shirt standing in a garden.
# 0, Two friends enjoy time spent together.
# 1, Several men in hard hats are operating a giant pulley system.
# 1, Workers look down from up above on a piece of equipment.
# 1, Two men working on a machine wearing hard hats.
# 1, Four men on top of a tall structure.
# 1, Three men on a large rig.
# 2, A child in a pink dress is climbing up a set of stairs in an entry way.
# 2, A little girl in a pink dress going into a wooden cabin.
# 2, A little girl climbing the stairs to her playhouse.
# 2, A little girl climbing into a wooden playhouse.
# 2, A girl going into a wooden building.
# 3, Someone in a blue shirt and hat is standing on stair and leaning against a window.
# 3, A man in a blue shirt is standing on a ladder cleaning a window.
# 3, A man on a ladder cleans the window of a tall building.
# 3, Man in blue shirt and jeans on ladder cleaning windows
# 3, A man on a ladder cleans a window
# 4, Two men, one in a gray shirt, one in a black shirt, standing near a stove.
# 4, Two guy cooking and joking around with the camera.
# 4, Two men in a kitchen cooking food on a stove.
# 4, Two men are at the stove preparing food.
# 4, Two men are cooking a meal.
# 5, Two people in the photo are playing the guitar and the other is poking at him.
# 5, A man in green holds a guitar while the other man observes his shirt.
# 5, A man is fixing the guitar players costume.
# 5, A guy stitching up another man's coat.
# 5, The two boys playing guitar
# 6, A man sits in a chair while holding a large stuffed animal of a lion.
# 6, A man is sitting on a chair holding a large stuffed animal.
# 6, A man completes the finishing touches on a stuffed lion.
# 6, A man holds a large stuffed lion toy.
# 6, A man is smiling at a stuffed lion
# 7, A girl is on rollerskates talking on her cellphone standing in a parking lot.
# 7, A trendy girl talking on her cellphone while gliding slowly down the street.
# 7, A young adult wearing rollerblades, holding a cellular phone to her ear.
# 7, There is a young girl on her cellphone while skating.
# 7, Woman talking on cellphone and wearing rollerskates.
# 8, An asian man wearing a black suit stands near a dark-haired woman and a brown-haired woman.
# 8, Three people are standing outside near large pipes and a metal railing.
# 8, A young woman walks past two young people dressed in hip black outfits.
# 8, A woman with a large purse is walking by a gate.
# 8, Several people standing outside a building.
# 9, Two men in Germany jumping over a rail at the same time without shirts.
# 9, Two youths are jumping over a roadside railing, at night.
# 9, Boys dancing on poles in the middle of the night.
# 9, Two men with no shirts jumping over a rail.
# 9, Two guys jumping over a gate together
# 10, Five ballet dancers caught mid jump in a dancing studio with sunlight coming through a window.
# 10, Ballet dancers in a studio practice jumping with wonderful form.
# 10, Five girls are leaping simultaneously in a dance practice room.
# 10, Five girls dancing and bending feet in ballet class.
# 10, A ballet class of five girls jumping in sequence.
